# %% [markdown]
# # LOAD LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
from datetime import datetime
from sklearn.model_selection import StratifiedShuffleSplit, StratifiedKFold, GridSearchCV, PredefinedSplit
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import root_mean_squared_error, r2_score
from sklearn.inspection import permutation_importance
from sklearn.feature_selection import RFE
from xgboost import XGBRegressor
from diive.core.io.files import load_parquet

# %% [markdown]
# # CONFIGURATION

# %%
START_DATE, END_DATE = '2023-11-08', '2025-06-05'
TARGET_FLUX = 'FN2O'
N_FOLDS = 10
MODEL_TYPE = 'XGBoost'  # Options: 'RandomForest' or 'XGBoost'
CROSSVAL_SPLIT = 'shuffle' # options: 'shuffle' or 'kfold' or 'custom_time_blocks' or 'time_blocks_eliza'
PARCEL_CERTAIN = True
LOG_TRANSFORM = True
ADD_ID = True
UNDERSAMPLE = False
PERMUTATION_SEL = False
RFE_SEL = True

# %% [markdown]
# # LOAD DATA

# %%
data_main = fluxes = load_parquet(filepath=r"../81.1_GapFillingDataset.parquet")
data_main = data_main.loc[START_DATE:END_DATE].copy()

# Add an id column to account for the proximity of values as the timestamp is continuous without gaps
if ADD_ID:
    data_main['id'] = range(0, len(data_main))

data_main
# Out:
# Loaded .parquet file ../81.1_GapFillingDataset.parquet (0.331 seconds).
#     --> Detected time resolution of <30 * Minutes> / 30min
#                      NEE_L3.3_CUT_50_QCF  FN2O_L3.3_CUT_50_QCF  FCH4_L3.3_CUT_50_QCF  NEE_L3.3_CUT_50_QCF0  FN2O_L3.3_CUT_50_QCF0  FCH4_L3.3_CUT_50_QCF0  NEE_U50_f_reddyproc  GPP_U50_f_reddyproc  Reco_U50_reddyproc parcel parcel_certainty  SW_IN_POT  prec         ta  ppfd  ...  ts_0.15_gfXG_diff12h  ts_0.15_gfXG_diff24h  ts_0.3_gfXG_diff6h  ts_0.3_gfXG_diff12h  ts_0.3_gfXG_diff24h  wfps_0.05_gfXG_diff6h  wfps_0.05_gfXG_diff12h  wfps_0.05_gfXG_diff24h  wfps_0.15_gfXG_diff6h  wfps_0.15_gfXG_diff12h  wfps_0.15_gfXG_diff24h  wfps_0.3_gfXG_diff6h  wfps_0.3_gfXG_diff12h  wfps_0.3_gfXG_diff24h     id
# TIMESTAMP_MIDDLE                                                                                                                                                                                                                                                                  ...
# 2023-11-08 00:15:00                  NaN             -0.111997             -3.231648                   NaN                    NaN              -3.231648             1.991226            -0.238835            1.752390      B          certain        0.0   0.0   5.333333   0.0  ...             -1.116706             -1.152150           -0.275176            -0.379151             2.956382              -1.867139                0.684108               -0.057099              -0.193433               -0.188894                0.055964             -1.641550              -0.086146               0.576043      0
# 2023-11-08 00:45:00                  NaN              0.100302                   NaN                   NaN               0.100302                    NaN             2.035776            -0.203400            1.832376      B          certain        0.0   0.0   5.966667   0.0  ...             -1.202539             -1.002316           -0.315639            -0.100172             2.819366              -3.607107                0.860526               -0.241229              -0.051464                0.009568                0.016644             -2.340741               0.001028               0.291943      1
# 2023-11-08 01:15:00                  NaN              0.239428                   NaN                   NaN               0.239428                    NaN             2.026159            -0.210755            1.815404      B          certain        0.0   0.0   5.833333   0.0  ...             -1.423575             -1.251268            0.154263             0.054827             2.845686              -2.065147                0.363886                0.902289              -0.146880                0.084459                0.138010             -0.829823               0.242660               0.618842      2
# 2023-11-08 01:45:00                  NaN             -0.184917              6.746138                   NaN                    NaN                    NaN             2.026159            -0.206519            1.819640      B          certain        0.0   0.0   5.866667   0.0  ...             -1.456775             -1.194985            0.190084             0.205121             2.216312              -2.011537                0.459781                0.395772              -0.234554               -0.023746                0.307449             -0.724752               0.260016               0.686303      3
# 2023-11-08 02:15:00                  NaN              0.358358              3.168362                   NaN               0.358358               3.168362             2.025592            -0.218648            1.806944      B          certain        0.0   0.0   5.766667   0.0  ...             -1.730865             -1.054997            0.243881             0.243286             1.087768              -1.790441                0.750873                1.037005              -0.187335               -0.028905                0.178615             -0.724348               0.032634               0.695635      4
# ...                                  ...                   ...                   ...                   ...                    ...                    ...                  ...                  ...                 ...    ...              ...        ...   ...        ...   ...  ...                   ...                   ...                 ...                  ...                  ...                    ...                     ...                     ...                    ...                     ...                     ...                   ...                    ...                    ...    ...
# 2025-06-05 21:45:00                  NaN                   NaN                   NaN                   NaN                    NaN                    NaN                  NaN                  NaN                 NaN   None             None        NaN   0.0  15.833333   0.0  ...              1.105808              0.251504            0.137646             0.269348            -0.182687              -1.770683               -2.475835               -0.177535              -1.379082               -1.916712               -1.061214             -4.208609              -5.629534              -3.817729  27643
# 2025-06-05 22:15:00                  NaN                   NaN                   NaN                   NaN                    NaN                    NaN                  NaN                  NaN                 NaN   None             None        NaN   0.0  15.733333   0.0  ...              1.185266              0.415243           -0.006586             0.174141            -0.309516              -4.491630               -2.066168               -1.321539              -1.091476               -1.879544               -0.962736             -4.909742              -6.854152              -4.700644  27644
# 2025-06-05 22:45:00                  NaN                   NaN                   NaN                   NaN                    NaN                    NaN                  NaN                  NaN                 NaN   None             None        NaN   0.0  16.200000   0.0  ...              0.829382              0.121118            0.319431             0.265461            -0.070498              -5.166902               -3.647422               -1.775911              -1.190896               -1.739450               -0.961502             -4.913663              -6.580284              -4.667567  27645
# 2025-06-05 23:15:00                  NaN                   NaN                   NaN                   NaN                    NaN                    NaN                  NaN                  NaN                 NaN   None             None        NaN   0.0  15.666667   0.0  ...              0.539066              0.180393           -0.000076             0.258007            -0.091505              -2.750279               -4.218001               -1.458660              -0.813121               -1.529689               -0.562181             -4.477950              -5.074361              -4.221220  27646
# 2025-06-05 23:45:00                  NaN                   NaN                   NaN                   NaN                    NaN                    NaN                  NaN                  NaN                 NaN   None             None        NaN   0.0  15.500000   0.0  ...              0.265738             -0.194086            0.107750             0.293407            -0.103312              -2.406771               -4.574129               -4.704248              -0.876899               -1.353004               -0.914459             -4.673740              -5.033116              -5.256283  27647
#
# [27648 rows x 236 columns]

# %% [markdown]
# # CLEAN DATA

# %%
TARGET = f'{TARGET_FLUX}_L3.3_CUT_50_QCF0'
print(f'The target variable is {TARGET}')

mean_nan_size = (
    data_main[TARGET]
    .isna()
    .ne(data_main[TARGET].isna().shift())
    .cumsum()
    .where(data_main[TARGET].isna())
    .dropna()
    .value_counts()
    .mean()
)
print("\nMean size of consecutive NaNs in the target variable:", mean_nan_size)

# Remove NAs
data = data_main[data_main[TARGET].notna()].copy()

# Keep only data where we are sure about parcel attribution
if PARCEL_CERTAIN:
    data = data[data['parcel_certainty'] == 'certain'].copy()
    print('\nKeeping only data when we are highly confident on the parcel attribution')

# Remove some variables that cannot mechanistically be related to N2O flux or hard to explain 
prefix = ('parcel')
inside = ('parcel')
to_drop = [c for c in data.columns if c.startswith(prefix) or inside in c]
data.drop(columns=to_drop, inplace=True)
print(f"Dropped {len(to_drop)} columns considered not to be relevant for the target based on knowledge: {to_drop}")

# Keep only variables of the chosen categories
# prefix = ('wfps', 'ts', 'prec', 'GPP', 'n_decay', 'NEE', 'Reco', 'timesince', TARGET)
# to_keep = [c for c in data.columns if c.startswith(prefix)]
# data = data[to_keep].copy()
# to_remove = [c for c in data.columns if 'parcelA' in c or 'parcelB' in c]
# data.drop(columns=to_remove, inplace=True)

# Remove any flux variable with target flux except for the target itself
to_drop = [col for col in data.columns if TARGET_FLUX in col]
# Leave the target!
to_drop.remove(TARGET)
data.drop(columns=to_drop, inplace=True)

def clean_data(df, threshold=0.05):
    """Remove columns with too many missing values and non-numeric columns."""
    dropped_missing = df.columns[df.isna().mean() > threshold].tolist()
    df = df.drop(columns=dropped_missing)
    dropped_non_numeric = df.select_dtypes(exclude=[np.number]).columns.tolist()
    df = df.select_dtypes(include=[np.number])
    print(f"\nDropped {len(dropped_missing)} due to missing values: {dropped_missing}")
    print(f"Dropped {len(dropped_non_numeric)} non-numeric columns: {dropped_non_numeric}")
    
    return df

data = clean_data(data)

data
# Out:
# The target variable is FN2O_L3.3_CUT_50_QCF0
#
# Mean size of consecutive NaNs in the target variable: 4.616
#
# Keeping only data when we are highly confident on the parcel attribution
# Dropped 16 columns considered not to be relevant for the target based on knowledge: ['parcel', 'parcel_certainty', 'n_decay_linear_parcelA', 'n_decay_linear_parcelB', 'n_decay_logistic_parcelA', 'n_decay_logistic_parcelB', 'n_decay_exponential_parcelA', 'n_decay_exponential_parcelB', 'n_decay_lognormal_parcelA', 'n_decay_lognormal_parcelB', 'n_decay_timed_parcelA', 'n_decay_timed_parcelB', 'timesince_fert_parcelA', 'timesince_fert_parcelB', 'fert_parcelA_timed', 'fert_parcelB_timed']
#
# Dropped 4 due to missing values: ['NEE_L3.3_CUT_50_QCF', 'FCH4_L3.3_CUT_50_QCF', 'NEE_L3.3_CUT_50_QCF0', 'FCH4_L3.3_CUT_50_QCF0']
# Dropped 0 non-numeric columns: []
#                      FN2O_L3.3_CUT_50_QCF0  NEE_U50_f_reddyproc  GPP_U50_f_reddyproc  Reco_U50_reddyproc  SW_IN_POT   prec         ta  ppfd  sw_in         rh  timesince_prec       vpd  ts_0.05_gfXG  ts_0.15_gfXG  ts_0.3_gfXG  ...  ts_0.15_gfXG_diff12h  ts_0.15_gfXG_diff24h  ts_0.3_gfXG_diff6h  ts_0.3_gfXG_diff12h  ts_0.3_gfXG_diff24h  wfps_0.05_gfXG_diff6h  wfps_0.05_gfXG_diff12h  wfps_0.05_gfXG_diff24h  wfps_0.15_gfXG_diff6h  wfps_0.15_gfXG_diff12h  wfps_0.15_gfXG_diff24h  wfps_0.3_gfXG_diff6h  wfps_0.3_gfXG_diff12h  wfps_0.3_gfXG_diff24h     id
# TIMESTAMP_MIDDLE                                                                                                                                                                                                                  ...
# 2023-11-08 00:45:00               0.100302             2.035776            -0.203400            1.832376        0.0  0.000   5.966667   0.0    0.0  77.500000            13.0  0.210078      6.817496      9.855426    10.933558  ...             -1.202539             -1.002316           -0.315639            -0.100172             2.819366              -3.607107                0.860526               -0.241229              -0.051464                0.009568                0.016644             -2.340741               0.001028               0.291943      1
# 2023-11-08 01:15:00               0.239428             2.026159            -0.210755            1.815404        0.0  0.000   5.833333   0.0    0.0  77.366667            14.0  0.209377      6.969578      9.790032    10.941941  ...             -1.423575             -1.251268            0.154263             0.054827             2.845686              -2.065147                0.363886                0.902289              -0.146880                0.084459                0.138010             -0.829823               0.242660               0.618842      2
# 2023-11-08 02:15:00               0.358358             2.025592            -0.218648            1.806944        0.0  0.000   5.766667   0.0    0.0  77.166667            16.0  0.210251      7.089032      9.802778    11.114241  ...             -1.730865             -1.054997            0.243881             0.243286             1.087768              -1.790441                0.750873                1.037005              -0.187335               -0.028905                0.178615             -0.724348               0.032634               0.695635      4
# 2023-11-08 03:15:00               0.070120             1.991226            -0.230492            1.760734        0.0  0.000   5.400000   0.0    0.0  76.300000            18.0  0.212734      7.258470      9.776045    10.794777  ...             -1.743717             -1.250376           -0.069672             0.010304             0.609105              -1.807428                0.507260                1.243841              -0.005498               -0.069987                0.059082              0.121729               0.069218               0.542432      6
# 2023-11-08 04:15:00              -0.545573             1.818380            -0.152503            1.665877        0.0  0.000   4.633333   0.0    0.0  79.433333            20.0  0.174974      7.059120     10.027685    10.725005  ...             -1.319282             -0.813456           -0.114923            -0.589170             0.650526              -1.449633                0.627440                1.279728               0.267424                0.068695                0.115496              0.390843               0.393405               0.937131      8
# ...                                    ...                  ...                  ...                 ...        ...    ...        ...   ...    ...        ...             ...       ...           ...           ...          ...  ...                   ...                   ...                 ...                  ...                  ...                    ...                     ...                     ...                    ...                     ...                     ...                   ...                    ...                    ...    ...
# 2025-06-04 21:15:00               0.282174            10.359786            -1.297718            9.062068        0.0  0.017  15.786667   0.0    0.0  82.716668             0.0  0.310466     18.385555     18.675556    17.300000  ...              0.975556             -0.947778            0.284444             0.305001            -0.229445              -0.121255               -0.853115               -1.277483              -0.177867               -0.529632               -0.893077             -0.144427              -0.967252              -1.448612  27594
# 2025-06-04 21:45:00               0.524032            10.578562            -1.558117            9.020445        0.0  0.017  15.693333   0.0    0.0  82.700000             0.0  0.308913     18.192778     18.566111    17.300000  ...              0.866111             -0.961666            0.205000             0.318334            -0.270000              -0.042154               -0.862990               -1.240195              -0.138894               -0.501428               -0.865616             -0.130630              -0.951387              -1.460515  27595
# 2025-06-04 22:45:00              -0.069384            10.095010            -1.089414            9.005596        0.0  0.425  15.660000   0.0    0.0  83.819999             0.0  0.288298     17.903888     18.398333    17.269444  ...              0.575555             -0.836111            0.098889             0.368333            -0.310000               0.025945               -0.847119               -1.197830              -0.108815               -0.438437               -0.860283             -0.205865              -0.852473              -1.503494  27597
# 2025-06-04 23:15:00              -0.288296             8.641342             0.341996            8.983338        0.0  0.782  15.610000   0.0    0.0  84.406666             0.0  0.276955     17.802222     18.301111    17.206667  ...              0.378889             -0.836667            0.008334             0.306667            -0.343888               0.020213               -0.806915               -1.162289              -0.126660               -0.455859               -0.851492             -0.372307              -0.755846              -1.441543  27598
# 2025-06-04 23:45:00               0.220511             8.664543             0.195977            8.860520        0.0  0.100  15.333333   0.0    0.0  80.533333             0.0  0.339665     17.836386     18.471004    17.231136  ...              0.417115             -0.588995            0.031136             0.331136            -0.279420               3.419480                2.615190                2.250656               0.291370               -0.017027               -0.404165              0.719143               0.398644              -0.325529  27599
#
# [8028 rows x 215 columns]

# %% [markdown]
# # IMBALANCE HANDLING

# %% [markdown]
# ## UNDER SAMPLING

# %%
if UNDERSAMPLE:
    quantile_cutoff = 0.8
    cutoff_value = data[TARGET].quantile(quantile_cutoff)
    print(f'Undersampling target data below: {cutoff_value}')
    # Split and undersample
    upper = data[data[TARGET] > cutoff_value]
    lower = data[data[TARGET] <= cutoff_value]
    # Undersample
    lower_sampled = lower.sample(frac=0.5, random_state=42)
    # Combine
    data = pd.concat([upper, lower_sampled]).sample(frac=1, random_state=42)
    # Resort data
    data = data.sort_index().reset_index(drop=False)  # keep the timestamp as a column
    data = data.set_index('TIMESTAMP_MIDDLE')    # and set it back as index if needed
    # Plot
    data[TARGET].plot(x_compat=True, style='.')
    plt.show()

# %% [markdown]
# ## LOG TRANSFORMATION

# %%
min_value = data[TARGET].min()

def log_transform(x):
    return np.log1p(x - min_value) if min_value < 0 else np.log1p(x)

def inverse_log_transform(x):
    return np.expm1(x) + min_value if min_value < 0 else np.expm1(x)

if LOG_TRANSFORM:
    data[TARGET] = log_transform(data[TARGET])

# Show histogram of TARGET
plt.hist(data[TARGET], bins=20)
plt.xlabel(TARGET)
plt.show()

# Show timeseries
data[TARGET].plot(x_compat=True, style='.');

data
# Out:
#                      FN2O_L3.3_CUT_50_QCF0  NEE_U50_f_reddyproc  GPP_U50_f_reddyproc  Reco_U50_reddyproc  SW_IN_POT   prec         ta  ppfd  sw_in         rh  timesince_prec       vpd  ts_0.05_gfXG  ts_0.15_gfXG  ts_0.3_gfXG  ...  ts_0.15_gfXG_diff12h  ts_0.15_gfXG_diff24h  ts_0.3_gfXG_diff6h  ts_0.3_gfXG_diff12h  ts_0.3_gfXG_diff24h  wfps_0.05_gfXG_diff6h  wfps_0.05_gfXG_diff12h  wfps_0.05_gfXG_diff24h  wfps_0.15_gfXG_diff6h  wfps_0.15_gfXG_diff12h  wfps_0.15_gfXG_diff24h  wfps_0.3_gfXG_diff6h  wfps_0.3_gfXG_diff12h  wfps_0.3_gfXG_diff24h     id
# TIMESTAMP_MIDDLE                                                                                                                                                                                                                  ...
# 2023-11-08 00:45:00               1.088437             2.035776            -0.203400            1.832376        0.0  0.000   5.966667   0.0    0.0  77.500000            13.0  0.210078      6.817496      9.855426    10.933558  ...             -1.202539             -1.002316           -0.315639            -0.100172             2.819366              -3.607107                0.860526               -0.241229              -0.051464                0.009568                0.016644             -2.340741               0.001028               0.291943      1
# 2023-11-08 01:15:00               1.134222             2.026159            -0.210755            1.815404        0.0  0.000   5.833333   0.0    0.0  77.366667            14.0  0.209377      6.969578      9.790032    10.941941  ...             -1.423575             -1.251268            0.154263             0.054827             2.845686              -2.065147                0.363886                0.902289              -0.146880                0.084459                0.138010             -0.829823               0.242660               0.618842      2
# 2023-11-08 02:15:00               1.171765             2.025592            -0.218648            1.806944        0.0  0.000   5.766667   0.0    0.0  77.166667            16.0  0.210251      7.089032      9.802778    11.114241  ...             -1.730865             -1.054997            0.243881             0.243286             1.087768              -1.790441                0.750873                1.037005              -0.187335               -0.028905                0.178615             -0.724348               0.032634               0.695635      4
# 2023-11-08 03:15:00               1.078221             1.991226            -0.230492            1.760734        0.0  0.000   5.400000   0.0    0.0  76.300000            18.0  0.212734      7.258470      9.776045    10.794777  ...             -1.743717             -1.250376           -0.069672             0.010304             0.609105              -1.807428                0.507260                1.243841              -0.005498               -0.069987                0.059082              0.121729               0.069218               0.542432      6
# 2023-11-08 04:15:00               0.843184             1.818380            -0.152503            1.665877        0.0  0.000   4.633333   0.0    0.0  79.433333            20.0  0.174974      7.059120     10.027685    10.725005  ...             -1.319282             -0.813456           -0.114923            -0.589170             0.650526              -1.449633                0.627440                1.279728               0.267424                0.068695                0.115496              0.390843               0.393405               0.937131      8
# ...                                    ...                  ...                  ...                 ...        ...    ...        ...   ...    ...        ...             ...       ...           ...           ...          ...  ...                   ...                   ...                 ...                  ...                  ...                    ...                     ...                     ...                    ...                     ...                     ...                   ...                    ...                    ...    ...
# 2025-06-04 21:15:00               1.147879            10.359786            -1.297718            9.062068        0.0  0.017  15.786667   0.0    0.0  82.716668             0.0  0.310466     18.385555     18.675556    17.300000  ...              0.975556             -0.947778            0.284444             0.305001            -0.229445              -0.121255               -0.853115               -1.277483              -0.177867               -0.529632               -0.893077             -0.144427              -0.967252              -1.448612  27594
# 2025-06-04 21:45:00               1.221820            10.578562            -1.558117            9.020445        0.0  0.017  15.693333   0.0    0.0  82.700000             0.0  0.308913     18.192778     18.566111    17.300000  ...              0.866111             -0.961666            0.205000             0.318334            -0.270000              -0.042154               -0.862990               -1.240195              -0.138894               -0.501428               -0.865616             -0.130630              -0.951387              -1.460515  27595
# 2025-06-04 22:45:00               1.029599            10.095010            -1.089414            9.005596        0.0  0.425  15.660000   0.0    0.0  83.819999             0.0  0.288298     17.903888     18.398333    17.269444  ...              0.575555             -0.836111            0.098889             0.368333            -0.310000               0.025945               -0.847119               -1.197830              -0.108815               -0.438437               -0.860283             -0.205865              -0.852473              -1.503494  27597
# 2025-06-04 23:15:00               0.948189             8.641342             0.341996            8.983338        0.0  0.782  15.610000   0.0    0.0  84.406666             0.0  0.276955     17.802222     18.301111    17.206667  ...              0.378889             -0.836667            0.008334             0.306667            -0.343888               0.020213               -0.806915               -1.162289              -0.126660               -0.455859               -0.851492             -0.372307              -0.755846              -1.441543  27598
# 2025-06-04 23:45:00               1.128119             8.664543             0.195977            8.860520        0.0  0.100  15.333333   0.0    0.0  80.533333             0.0  0.339665     17.836386     18.471004    17.231136  ...              0.417115             -0.588995            0.031136             0.331136            -0.279420               3.419480                2.615190                2.250656               0.291370               -0.017027               -0.404165              0.719143               0.398644              -0.325529  27599
#
# [8028 rows x 215 columns]

# %% [markdown]
# # CROSS-VAL SPLITS

# %% [markdown]
# Using stratified approach based on the target variable

# %%
def create_splits(X, y, n_folds, test_size=0.2, random_state=42, n_bins=5):
    """Creates train-test splits using StratifiedShuffleSplit or StratifiedKFold with equal-width binning."""
    
    # Use pd.cut to create equal-width bins (avoids empty bins issue)
    y_binned = pd.cut(y, bins=n_bins, labels=False, include_lowest=True)

    # Select method for stratified splitting
    if CROSSVAL_SPLIT == "shuffle":
        splitter = StratifiedShuffleSplit(n_splits=n_folds, test_size=test_size, random_state=random_state)
    elif CROSSVAL_SPLIT == "kfold":
        splitter = StratifiedKFold(n_splits=n_folds, shuffle=False)

    # Generate train-test splits
    splits = [(train_idx, test_idx) for train_idx, test_idx in splitter.split(X, y_binned)]

    return splits

if CROSSVAL_SPLIT == 'time_blocks_eliza':
    def create_splits(X, y, n_folds, split=0.2, mean_block=24, min_block=1, random_state=42): # you can set mean block to mean_nan_size
        """Generates multiple train-test index splits using block-based cross-validation by varying the random seed."""
        splits = []
        total_test = round(len(X) * split)
        n_blocks = round(total_test/mean_block)

        if mean_block < min_block:
            raise ValueError("Min block size is too large for the number of blocks.")

        for fold in range(n_folds):
            np.random.seed(random_state + fold)  # Change seed for each fold
            
            tt = np.zeros(len(X))  # Array to store train-test assignments

            # Generate random block sizes with normal variation
            blocks = np.array([max(min_block, mean_block + round(v)) 
                            for v in np.random.normal(0, mean_block / 10, n_blocks)])

            # Randomly shuffle the starting positions of test blocks
            available_positions = np.arange(len(X))  # Possible start positions
            np.random.shuffle(available_positions)   # Shuffle them

            # Assign blocks sequentially based on shuffled positions
            assigned = set()
            for b in blocks:
                if len(assigned) >= total_test:
                    break
                # Pick a random starting position
                istart = np.random.choice(available_positions)
                iend = min(istart + int(b), len(X))

                # Ensure blocks don't overlap significantly
                assigned.update(range(istart, iend))
                tt[istart:iend] = 1

            train_idx = np.where(tt == 0)[0]
            test_idx = np.where(tt == 1)[0]
            
            splits.append((train_idx, test_idx))

        return splits
    
if CROSSVAL_SPLIT == 'custom_time_blocks':
    def create_splits(X, y, n_folds=5, test_fraction=0.2, block_duration='1D',
                    min_gap='6D', buffer_gap='1D', seed=None):
        """
        Time-block CV with buffer and min_gap enforcement, allowing partial blocks to match test_fraction.
        """
        if seed is not None:
            np.random.seed(seed)

        total_rows = len(X)
        total_test_target = int(total_rows * test_fraction)
        all_times = X.index
        block_dur = pd.to_timedelta(block_duration)
        min_gap_dur = pd.to_timedelta(min_gap)
        buffer_gap_dur = pd.to_timedelta(buffer_gap)

        # Generate all possible block start times
        possible_starts = all_times[(all_times + block_dur) <= all_times[-1]]
        splits = []

        for fold in range(n_folds):
            test_indices = set()
            buffer_indices = set()
            selected_blocks = []

            shuffled_starts = np.random.permutation(possible_starts)

            for start_time in shuffled_starts:
                end_time = start_time + block_dur
                buffer_start = start_time - buffer_gap_dur
                buffer_end = end_time + buffer_gap_dur

                # Enforce min_gap between selected test blocks
                if any(abs(pd.Timedelta(start_time - sel).total_seconds()) < min_gap_dur.total_seconds()
                    for sel in selected_blocks):
                    continue

                block_mask = (all_times >= start_time) & (all_times < end_time)
                buffer_mask = (all_times >= buffer_start) & (all_times < buffer_end)

                block_idx = np.where(block_mask)[0]
                buffer_idx = np.where(buffer_mask)[0]

                if len(block_idx) == 0:
                    continue

                # Allow trimming final block if needed
                remaining = total_test_target - len(test_indices)
                if remaining <= 0:
                    break
                if len(block_idx) > remaining:
                    block_idx = block_idx[:remaining]

                # Check again for overlap with buffer
                if any(i in buffer_indices for i in block_idx):
                    continue

                test_indices.update(block_idx)
                buffer_indices.update(buffer_idx)
                selected_blocks.append(start_time)

                if len(test_indices) >= total_test_target:
                    break

            train_indices = sorted(set(range(total_rows)) - test_indices - buffer_indices)
            splits.append((np.array(train_indices), np.array(sorted(test_indices))))

        return splits

X = data.drop(columns=TARGET)
y = data[TARGET]
# Create the splits using StratifiedShuffleSplit
cross_val_splits = create_splits(X, y, n_folds=N_FOLDS)


# --- PLOT TRAIN-TEST SPLITS ---
n_rows = math.ceil(N_FOLDS / 2)  # Ensure enough rows for all splits
fig, axes = plt.subplots(n_rows, 2, figsize=(14, 8))
axes = axes.flatten()  # Flatten the axes array to make iteration easier

for i, (train_idx, test_idx) in enumerate(cross_val_splits):
    train_idx_mapped = X.iloc[train_idx].index
    test_idx_mapped = X.iloc[test_idx].index

    # Plot train and test points
    axes[i].plot(y.loc[train_idx_mapped].index, y.loc[train_idx_mapped], '.', label='Train', color="blue")
    axes[i].plot(y.loc[test_idx_mapped].index, y.loc[test_idx_mapped], 'x', label='Test', color="red")
    
    axes[i].set_title(f"Split {i + 1} ({CROSSVAL_SPLIT})")
    axes[i].legend()

# Hide unused subplots if n_folds is odd
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# # FEATURE SELECTION

# %% [markdown]
# ## Permutation importance

# %%
N_REPEATS = 5
N_RANDOMS = 10 
def permutation_importance_selection(X, y, n_repeats=N_REPEATS, n_randoms=N_RANDOMS):
    iteration = 0

    # Generate random features ONCE and keep them throughout the iterations
    np.random.seed(42)  # Ensures reproducibility
    for i in range(n_randoms):
        X[f'random_{i}'] = np.random.permutation(len(X))

    while True:
        iteration += 1
        print(f"Iteration {iteration}: Starting with {X.shape[1] - n_randoms} features")

        model = RandomForestRegressor(n_estimators=100, min_samples_split=10, min_samples_leaf=5, random_state=42, n_jobs=-1) \
            if MODEL_TYPE == 'RandomForest' else XGBRegressor(n_estimators=100, random_state=42, n_jobs=-1)
        importance_scores, rmse_scores, r2_scores = [], [], []

        for train_idx, test_idx in cross_val_splits:
            X_train, y_train, X_test, y_test = X.iloc[train_idx], y.iloc[train_idx], X.iloc[test_idx], y.iloc[test_idx]
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)

            # Invert the transformation if it was applied to calculate the performance with the original scale
            if LOG_TRANSFORM:
                y_test, y_pred = inverse_log_transform(y_test), inverse_log_transform(y_pred)

            perm_importance = permutation_importance(model, X_test, y_test, n_repeats=n_repeats, random_state=42, n_jobs=-1)
            importance_scores.append(perm_importance.importances_mean)
            rmse_scores.append(root_mean_squared_error(y_test, y_pred))
            r2_scores.append(r2_score(y_test, y_pred))

        mean_importance = np.mean(importance_scores, axis=0)
        threshold = np.mean(mean_importance[-n_randoms:])  # Use average of random features as threshold
        
        to_remove = [col for col in X.columns if mean_importance[X.columns.get_loc(col)] < threshold and not col.startswith('random_')]
        to_keep = [col for col in X.columns if col not in to_remove]
        print(f"Iteration {iteration}: Removed {len(to_remove)} features, RMSE: {np.mean(rmse_scores):.4f}, R²: {np.mean(r2_scores):.4f}")
        
        if len(to_remove) == 0:
            break  # Stop when no features are removed

        X = X[to_keep].copy()

    # Remove random features from final selection
    to_keep = [col for col in to_keep if not col.startswith('random_')]
    return to_keep


if PERMUTATION_SEL:
    to_keep = permutation_importance_selection(data.drop(columns=[TARGET]), data[TARGET])
    data = data[to_keep + [TARGET]]
    to_keep

# %% [markdown]
# ## Recursive feature elimination

# %%
def rfe_selection(X, y, cross_val_splits):
    performance = []
    iteration = 0
    features = list(X.columns)
    feature_removal_order = []  # Store removed features and their iteration index

    while len(features) > 1:
        iteration += 1
        rmse_scores, r2_scores, importances = [], [], []

        for train_idx, test_idx in cross_val_splits:
            X_train, y_train, X_test, y_test = X[features].iloc[train_idx], y.iloc[train_idx], X[features].iloc[test_idx], y.iloc[test_idx]
            model = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1) if MODEL_TYPE == 'RandomForest' else XGBRegressor(n_estimators=100, random_state=42, n_jobs=-1)
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)
            
            # Invert the transformation if it was applied to calculate the performance with the original scale
            if LOG_TRANSFORM:
                y_test, y_pred = inverse_log_transform(y_test), inverse_log_transform(y_pred)
            
            rmse_scores.append(root_mean_squared_error(y_test, y_pred))
            r2_scores.append(r2_score(y_test, y_pred))
            importances.append(model.feature_importances_)

        mean_rmse = np.mean(rmse_scores)
        mean_r2 = np.mean(r2_scores)
        performance.append((features.copy(), mean_rmse, mean_r2))

        mean_importances = np.mean(importances, axis=0)
        least_important_index = np.argmin(mean_importances)
        least_important_feature = features.pop(least_important_index)

        # Store the removed feature with its iteration index
        feature_removal_order.append((least_important_feature, iteration))

        print(f"Iteration {iteration}: Remaining features: {len(features)}, Removed: {least_important_feature}, RMSE: {mean_rmse:.4f}, R²: {mean_r2:.4f}")

    # Extract RMSE and R² values
    rmse_values = [score[1] for score in performance]
    r2_values = [score[2] for score in performance]

    # Plot RMSE and R² over iterations
    fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)
    axs[0].plot(range(len(performance)), rmse_values, label="Cross-validated RMSE")
    axs[0].set_ylabel("RMSE")
    axs[0].legend()

    axs[1].plot(range(len(performance)), r2_values, label="Cross-validated R²", color="orange")
    axs[1].set_xlabel("Iteration")
    axs[1].set_ylabel("R²")
    axs[1].legend()

    plt.tight_layout()
    plt.show()

    # Select best feature set by minimizing both R² and RMSE and penlizing larger feature sets
    # Normalize RMSE and R²
    norm_rmse = (np.array(rmse_values) - min(rmse_values)) / (max(rmse_values) - min(rmse_values))
    norm_r2 = (np.array(r2_values) - min(r2_values)) / (max(r2_values) - min(r2_values))
    # Set weights for normalized metrics
    w_rmse, w_r2, w_penalty = 0.5, 0.5, 0.01  # Adjust w_penalty as needed
    # Calculate composite scores with normalized metrics and feature count penalty
    composite_scores = [
        (performance[i][0], # Features
         i + 1, # Iteration number
        w_rmse * norm_rmse[i] + w_r2 * (1 - norm_r2[i]) + w_penalty * len(performance[i][0])  # Composite score
        )  
        for i in range(len(performance))
    ]

    # Find the feature subset with the best (lowest) composite score
    best_features, best_iteration, _ = min(composite_scores, key=lambda x: x[2])

    # Add the final remaining feature
    feature_removal_order.append((features[0], iteration + 1))

    # Rank features based on removal order
    feature_ranking = [feature for feature, _ in sorted(feature_removal_order, key=lambda x: x[1], reverse=True)]

    # Print the best feature set details
    print(f"\nBest feature set found at iteration {best_iteration}:")
    print(f"Selected Features: {best_features}")
    print(f"Performance - RMSE: {rmse_values[best_iteration-1]:.4f}, R²: {r2_values[best_iteration-1]:.4f}")

    return best_features, feature_ranking

if RFE_SEL:
    selected_features, ranked_features = rfe_selection(data.drop(columns=[TARGET]), data[TARGET], cross_val_splits= cross_val_splits)
    # Update the main dataframe
    data = data[selected_features + [TARGET]]
# Out:
# Iteration 1: Remaining features: 213, Removed: soil_preparation_timed, RMSE: 0.4749, R²: 0.9491
# Iteration 2: Remaining features: 212, Removed: harvest_timed, RMSE: 0.4749, R²: 0.9491
# Iteration 3: Remaining features: 211, Removed: fert_timed, RMSE: 0.4746, R²: 0.9492
# Iteration 4: Remaining features: 210, Removed: NEE_U50_f_reddyproc, RMSE: 0.4736, R²: 0.9494
# Iteration 5: Remaining features: 209, Removed: SW_IN_POT, RMSE: 0.4752, R²: 0.9491
# Iteration 6: Remaining features: 208, Removed: GPP_U50_f_reddyproc, RMSE: 0.4668, R²: 0.9509
# Iteration 7: Remaining features: 207, Removed: Reco_U50_reddyproc, RMSE: 0.4794, R²: 0.9487
# Iteration 8: Remaining features: 206, Removed: ta, RMSE: 0.4809, R²: 0.9482
# Iteration 9: Remaining features: 205, Removed: prec, RMSE: 0.5041, R²: 0.9427
# Iteration 10: Remaining features: 204, Removed: rh, RMSE: 0.4932, R²: 0.9451
# Iteration 11: Remaining features: 203, Removed: ts_0.15_gfXG_lag3h_roll3hmean, RMSE: 0.4802, R²: 0.9479
# Iteration 12: Remaining features: 202, Removed: ta_lag9h, RMSE: 0.4897, R²: 0.9460
# Iteration 13: Remaining features: 201, Removed: ts_0.15_gfXG_lag3h_roll6hmean, RMSE: 0.4866, R²: 0.9467
# Iteration 14: Remaining features: 200, Removed: timesince_prec, RMSE: 0.4831, R²: 0.9474
# Iteration 15: Remaining features: 199, Removed: ts_0.05_gfXG, RMSE: 0.4793, R²: 0.9484
# Iteration 16: Remaining features: 198, Removed: ts_0.15_gfXG, RMSE: 0.4707, R²: 0.9503
# Iteration 17: Remaining features: 197, Removed: NEE_U50_f_reddyproc_lag3h, RMSE: 0.4740, R²: 0.9495
# Iteration 18: Remaining features: 196, Removed: NEE_U50_f_reddyproc_lag6h, RMSE: 0.4870, R²: 0.9467
# Iteration 19: Remaining features: 195, Removed: NEE_U50_f_reddyproc_lag9h, RMSE: 0.4566, R²: 0.9535
# Iteration 20: Remaining features: 194, Removed: GPP_U50_f_reddyproc_lag9h, RMSE: 0.4557, R²: 0.9535
# Iteration 21: Remaining features: 193, Removed: GPP_U50_f_reddyproc_lag3h, RMSE: 0.4633, R²: 0.9521
# Iteration 22: Remaining features: 192, Removed: prec_lag6h, RMSE: 0.4485, R²: 0.9549
# Iteration 23: Remaining features: 191, Removed: prec_lag9h, RMSE: 0.4596, R²: 0.9529
# Iteration 24: Remaining features: 190, Removed: GPP_U50_f_reddyproc_lag6h, RMSE: 0.4489, R²: 0.9551
# Iteration 25: Remaining features: 189, Removed: prec_lag3h, RMSE: 0.4574, R²: 0.9535
# Iteration 26: Remaining features: 188, Removed: NEE_U50_f_reddyproc_lag9h_roll3hsum, RMSE: 0.4566, R²: 0.9535
# Iteration 27: Remaining features: 187, Removed: ta_lag3h, RMSE: 0.4635, R²: 0.9523
# Iteration 28: Remaining features: 186, Removed: ta_lag6h_roll6hmean, RMSE: 0.4665, R²: 0.9517
# Iteration 29: Remaining features: 185, Removed: ts_0.15_gfXG_lag3h_roll9hmean, RMSE: 0.4711, R²: 0.9506
# Iteration 30: Remaining features: 184, Removed: GPP_U50_f_reddyproc_lag6h_roll3hsum, RMSE: 0.4633, R²: 0.9522
# Iteration 31: Remaining features: 183, Removed: Reco_U50_reddyproc_lag6h, RMSE: 0.4632, R²: 0.9523
# Iteration 32: Remaining features: 182, Removed: Reco_U50_reddyproc_lag9h, RMSE: 0.4582, R²: 0.9533
# Iteration 33: Remaining features: 181, Removed: ts_0.05_gfXG_lag6h, RMSE: 0.4557, R²: 0.9539
# Iteration 34: Remaining features: 180, Removed: ts_0.15_gfXG_lag3h, RMSE: 0.4587, R²: 0.9533
# Iteration 35: Remaining features: 179, Removed: NEE_U50_f_reddyproc_lag3h_roll9hsum, RMSE: 0.4665, R²: 0.9516
# Iteration 36: Remaining features: 178, Removed: ts_0.05_gfXG_lag9h, RMSE: 0.4616, R²: 0.9527
# Iteration 37: Remaining features: 177, Removed: GPP_U50_f_reddyproc_lag9h_roll6hsum, RMSE: 0.4658, R²: 0.9517
# Iteration 38: Remaining features: 176, Removed: ts_0.15_gfXG_lag6h_roll9hmean, RMSE: 0.4556, R²: 0.9539
# Iteration 39: Remaining features: 175, Removed: NEE_U50_f_reddyproc_lag3h_roll3hsum, RMSE: 0.4553, R²: 0.9539
# Iteration 40: Remaining features: 174, Removed: NEE_U50_f_reddyproc_lag6h_roll3hsum, RMSE: 0.4488, R²: 0.9552
# Iteration 41: Remaining features: 173, Removed: wfps_0.3_gfXG_roll3hmean, RMSE: 0.4533, R²: 0.9543
# Iteration 42: Remaining features: 172, Removed: Reco_U50_reddyproc_lag3h, RMSE: 0.4530, R²: 0.9543
# Iteration 43: Remaining features: 171, Removed: wfps_0.05_gfXG_lag6h_roll6hmean, RMSE: 0.4682, R²: 0.9513
# Iteration 44: Remaining features: 170, Removed: NEE_U50_f_reddyproc_lag6h_roll9hsum, RMSE: 0.4675, R²: 0.9513
# Iteration 45: Remaining features: 169, Removed: GPP_U50_f_reddyproc_lag9h_roll3hsum, RMSE: 0.4507, R²: 0.9548
# Iteration 46: Remaining features: 168, Removed: GPP_U50_f_reddyproc_lag9h_roll9hsum, RMSE: 0.4662, R²: 0.9517
# Iteration 47: Remaining features: 167, Removed: ts_0.15_gfXG_lag6h, RMSE: 0.4558, R²: 0.9536
# Iteration 48: Remaining features: 166, Removed: ta_lag6h, RMSE: 0.4630, R²: 0.9521
# Iteration 49: Remaining features: 165, Removed: prec_lag6h_roll3hsum, RMSE: 0.4533, R²: 0.9542
# Iteration 50: Remaining features: 164, Removed: NEE_U50_f_reddyproc_lag9h_roll6hsum, RMSE: 0.4570, R²: 0.9531
# Iteration 51: Remaining features: 163, Removed: prec_lag9h_roll3hsum, RMSE: 0.4564, R²: 0.9535
# Iteration 52: Remaining features: 162, Removed: NEE_U50_f_reddyproc_roll6hsum, RMSE: 0.4615, R²: 0.9524
# Iteration 53: Remaining features: 161, Removed: NEE_U50_f_reddyproc_lag3h_roll6hsum, RMSE: 0.4645, R²: 0.9519
# Iteration 54: Remaining features: 160, Removed: ts_0.15_gfXG_lag6h_roll3hmean, RMSE: 0.4602, R²: 0.9528
# Iteration 55: Remaining features: 159, Removed: wfps_0.15_gfXG_diff12h, RMSE: 0.4583, R²: 0.9531
# Iteration 56: Remaining features: 158, Removed: Reco_U50_reddyproc_lag6h_roll9hsum, RMSE: 0.4696, R²: 0.9509
# Iteration 57: Remaining features: 157, Removed: ts_0.3_gfXG_diff12h, RMSE: 0.4616, R²: 0.9525
# Iteration 58: Remaining features: 156, Removed: prec_lag3h_roll3hsum, RMSE: 0.4700, R²: 0.9508
# Iteration 59: Remaining features: 155, Removed: ts_0.05_gfXG_diff24h, RMSE: 0.4725, R²: 0.9504
# Iteration 60: Remaining features: 154, Removed: wfps_0.15_gfXG, RMSE: 0.4563, R²: 0.9534
# Iteration 61: Remaining features: 153, Removed: ts_0.05_gfXG_lag9h_roll3hmean, RMSE: 0.4607, R²: 0.9527
# Iteration 62: Remaining features: 152, Removed: NEE_U50_f_reddyproc_lag6h_roll6hsum, RMSE: 0.4706, R²: 0.9505
# Iteration 63: Remaining features: 151, Removed: vpd, RMSE: 0.4564, R²: 0.9537
# Iteration 64: Remaining features: 150, Removed: wfps_0.05_gfXG_roll9hmean, RMSE: 0.4567, R²: 0.9536
# Iteration 65: Remaining features: 149, Removed: wfps_0.05_gfXG_lag6h, RMSE: 0.4603, R²: 0.9527
# Iteration 66: Remaining features: 148, Removed: ta_lag6h_roll3hmean, RMSE: 0.4631, R²: 0.9520
# Iteration 67: Remaining features: 147, Removed: ta_lag3h_roll6hmean, RMSE: 0.4708, R²: 0.9502
# Iteration 68: Remaining features: 146, Removed: ts_0.05_gfXG_lag3h, RMSE: 0.4670, R²: 0.9513
# Iteration 69: Remaining features: 145, Removed: wfps_0.3_gfXG_diff6h, RMSE: 0.4655, R²: 0.9515
# Iteration 70: Remaining features: 144, Removed: prec_roll6hsum, RMSE: 0.4650, R²: 0.9517
# Iteration 71: Remaining features: 143, Removed: GPP_U50_f_reddyproc_lag6h_roll9hsum, RMSE: 0.4616, R²: 0.9523
# Iteration 72: Remaining features: 142, Removed: GPP_U50_f_reddyproc_lag3h_roll3hsum, RMSE: 0.4641, R²: 0.9517
# Iteration 73: Remaining features: 141, Removed: GPP_U50_f_reddyproc_lag6h_roll6hsum, RMSE: 0.4738, R²: 0.9499
# Iteration 74: Remaining features: 140, Removed: ts_0.15_gfXG_diff6h, RMSE: 0.4657, R²: 0.9516
# Iteration 75: Remaining features: 139, Removed: wfps_0.3_gfXG_lag6h_roll3hmean, RMSE: 0.4665, R²: 0.9514
# Iteration 76: Remaining features: 138, Removed: Reco_U50_reddyproc_lag9h_roll6hsum, RMSE: 0.4650, R²: 0.9518
# Iteration 77: Remaining features: 137, Removed: wfps_0.3_gfXG_lag6h, RMSE: 0.4591, R²: 0.9531
# Iteration 78: Remaining features: 136, Removed: ts_0.05_gfXG_roll9hmean, RMSE: 0.4611, R²: 0.9527
# Iteration 79: Remaining features: 135, Removed: wfps_0.3_gfXG_lag9h, RMSE: 0.4655, R²: 0.9519
# Iteration 80: Remaining features: 134, Removed: GPP_U50_f_reddyproc_lag3h_roll6hsum, RMSE: 0.4567, R²: 0.9534
# Iteration 81: Remaining features: 133, Removed: ts_0.05_gfXG_lag6h_roll9hmean, RMSE: 0.4606, R²: 0.9528
# Iteration 82: Remaining features: 132, Removed: wfps_0.15_gfXG_lag9h_roll6hmean, RMSE: 0.4679, R²: 0.9511
# Iteration 83: Remaining features: 131, Removed: ts_0.15_gfXG_diff12h, RMSE: 0.4728, R²: 0.9501
# Iteration 84: Remaining features: 130, Removed: ts_0.05_gfXG_lag9h_roll9hmean, RMSE: 0.4678, R²: 0.9511
# Iteration 85: Remaining features: 129, Removed: prec_lag6h_roll6hsum, RMSE: 0.4580, R²: 0.9532
# Iteration 86: Remaining features: 128, Removed: wfps_0.3_gfXG_roll6hmean, RMSE: 0.4541, R²: 0.9539
# Iteration 87: Remaining features: 127, Removed: ta_lag3h_roll9hmean, RMSE: 0.4493, R²: 0.9549
# Iteration 88: Remaining features: 126, Removed: ts_0.3_gfXG_diff6h, RMSE: 0.4749, R²: 0.9496
# Iteration 89: Remaining features: 125, Removed: ts_0.3_gfXG_diff24h, RMSE: 0.4667, R²: 0.9515
# Iteration 90: Remaining features: 124, Removed: NEE_U50_f_reddyproc_roll9hsum, RMSE: 0.4659, R²: 0.9514
# Iteration 91: Remaining features: 123, Removed: wfps_0.05_gfXG_diff6h, RMSE: 0.4538, R²: 0.9540
# Iteration 92: Remaining features: 122, Removed: ts_0.05_gfXG_lag3h_roll9hmean, RMSE: 0.4593, R²: 0.9528
# Iteration 93: Remaining features: 121, Removed: ta_lag9h_roll3hmean, RMSE: 0.4562, R²: 0.9534
# Iteration 94: Remaining features: 120, Removed: prec_lag9h_roll6hsum, RMSE: 0.4675, R²: 0.9512
# Iteration 95: Remaining features: 119, Removed: wfps_0.05_gfXG_roll6hmean, RMSE: 0.4569, R²: 0.9534
# Iteration 96: Remaining features: 118, Removed: ts_0.15_gfXG_diff24h, RMSE: 0.4588, R²: 0.9530
# Iteration 97: Remaining features: 117, Removed: NEE_U50_f_reddyproc_roll3hsum, RMSE: 0.4761, R²: 0.9491
# Iteration 98: Remaining features: 116, Removed: ts_0.05_gfXG_lag3h_roll6hmean, RMSE: 0.4481, R²: 0.9550
# Iteration 99: Remaining features: 115, Removed: prec_roll3hsum, RMSE: 0.4482, R²: 0.9552
# Iteration 100: Remaining features: 114, Removed: wfps_0.3_gfXG_diff12h, RMSE: 0.4586, R²: 0.9530
# Iteration 101: Remaining features: 113, Removed: wfps_0.3_gfXG_lag6h_roll6hmean, RMSE: 0.4560, R²: 0.9533
# Iteration 102: Remaining features: 112, Removed: ts_0.3_gfXG_lag3h, RMSE: 0.4606, R²: 0.9523
# Iteration 103: Remaining features: 111, Removed: wfps_0.05_gfXG_lag9h_roll6hmean, RMSE: 0.4590, R²: 0.9529
# Iteration 104: Remaining features: 110, Removed: ta_lag9h_roll9hmean, RMSE: 0.4519, R²: 0.9543
# Iteration 105: Remaining features: 109, Removed: ts_0.3_gfXG_lag3h_roll3hmean, RMSE: 0.4602, R²: 0.9528
# Iteration 106: Remaining features: 108, Removed: ts_0.15_gfXG_lag9h, RMSE: 0.4584, R²: 0.9532
# Iteration 107: Remaining features: 107, Removed: ts_0.15_gfXG_lag6h_roll6hmean, RMSE: 0.4681, R²: 0.9511
# Iteration 108: Remaining features: 106, Removed: NEE_U50_f_reddyproc_lag9h_roll9hsum, RMSE: 0.4629, R²: 0.9522
# Iteration 109: Remaining features: 105, Removed: ts_0.05_gfXG_lag9h_roll6hmean, RMSE: 0.4613, R²: 0.9522
# Iteration 110: Remaining features: 104, Removed: ts_0.05_gfXG_lag6h_roll6hmean, RMSE: 0.4503, R²: 0.9546
# Iteration 111: Remaining features: 103, Removed: wfps_0.3_gfXG_lag3h_roll3hmean, RMSE: 0.4610, R²: 0.9523
# Iteration 112: Remaining features: 102, Removed: GPP_U50_f_reddyproc_lag3h_roll9hsum, RMSE: 0.4634, R²: 0.9518
# Iteration 113: Remaining features: 101, Removed: wfps_0.15_gfXG_diff6h, RMSE: 0.4612, R²: 0.9528
# Iteration 114: Remaining features: 100, Removed: wfps_0.05_gfXG_lag9h_roll3hmean, RMSE: 0.4521, R²: 0.9546
# Iteration 115: Remaining features: 99, Removed: GPP_U50_f_reddyproc_roll6hsum, RMSE: 0.4642, R²: 0.9521
# Iteration 116: Remaining features: 98, Removed: ta_roll9hmean, RMSE: 0.4575, R²: 0.9534
# Iteration 117: Remaining features: 97, Removed: Reco_U50_reddyproc_lag6h_roll3hsum, RMSE: 0.4626, R²: 0.9524
# Iteration 118: Remaining features: 96, Removed: wfps_0.05_gfXG_lag3h_roll9hmean, RMSE: 0.4598, R²: 0.9529
# Iteration 119: Remaining features: 95, Removed: ts_0.05_gfXG_lag6h_roll3hmean, RMSE: 0.4581, R²: 0.9532
# Iteration 120: Remaining features: 94, Removed: Reco_U50_reddyproc_lag3h_roll6hsum, RMSE: 0.4609, R²: 0.9525
# Iteration 121: Remaining features: 93, Removed: wfps_0.05_gfXG_lag6h_roll9hmean, RMSE: 0.4545, R²: 0.9540
# Iteration 122: Remaining features: 92, Removed: wfps_0.3_gfXG_lag9h_roll9hmean, RMSE: 0.4564, R²: 0.9538
# Iteration 123: Remaining features: 91, Removed: prec_roll9hsum, RMSE: 0.4554, R²: 0.9539
# Iteration 124: Remaining features: 90, Removed: ts_0.15_gfXG_roll3hmean, RMSE: 0.4474, R²: 0.9555
# Iteration 125: Remaining features: 89, Removed: ts_0.05_gfXG_roll6hmean, RMSE: 0.4533, R²: 0.9543
# Iteration 126: Remaining features: 88, Removed: ta_roll6hmean, RMSE: 0.4597, R²: 0.9529
# Iteration 127: Remaining features: 87, Removed: GPP_U50_f_reddyproc_roll9hsum, RMSE: 0.4460, R²: 0.9556
# Iteration 128: Remaining features: 86, Removed: Reco_U50_reddyproc_lag6h_roll6hsum, RMSE: 0.4519, R²: 0.9545
# Iteration 129: Remaining features: 85, Removed: wfps_0.05_gfXG_lag3h_roll3hmean, RMSE: 0.4521, R²: 0.9543
# Iteration 130: Remaining features: 84, Removed: ta_lag9h_roll6hmean, RMSE: 0.4627, R²: 0.9524
# Iteration 131: Remaining features: 83, Removed: Reco_U50_reddyproc_roll9hsum, RMSE: 0.4402, R²: 0.9569
# Iteration 132: Remaining features: 82, Removed: wfps_0.05_gfXG_diff24h, RMSE: 0.4617, R²: 0.9522
# Iteration 133: Remaining features: 81, Removed: ts_0.05_gfXG_diff12h, RMSE: 0.4586, R²: 0.9530
# Iteration 134: Remaining features: 80, Removed: wfps_0.3_gfXG_diff24h, RMSE: 0.4608, R²: 0.9528
# Iteration 135: Remaining features: 79, Removed: ts_0.3_gfXG, RMSE: 0.4524, R²: 0.9543
# Iteration 136: Remaining features: 78, Removed: ts_0.3_gfXG_lag6h, RMSE: 0.4534, R²: 0.9539
# Iteration 137: Remaining features: 77, Removed: ts_0.05_gfXG_lag3h_roll3hmean, RMSE: 0.4547, R²: 0.9538
# Iteration 138: Remaining features: 76, Removed: ts_0.05_gfXG_diff6h, RMSE: 0.4658, R²: 0.9514
# Iteration 139: Remaining features: 75, Removed: ta_lag6h_roll9hmean, RMSE: 0.4468, R²: 0.9553
# Iteration 140: Remaining features: 74, Removed: wfps_0.15_gfXG_lag6h_roll9hmean, RMSE: 0.4547, R²: 0.9536
# Iteration 141: Remaining features: 73, Removed: wfps_0.15_gfXG_lag3h, RMSE: 0.4559, R²: 0.9535
# Iteration 142: Remaining features: 72, Removed: wfps_0.15_gfXG_roll6hmean, RMSE: 0.4588, R²: 0.9528
# Iteration 143: Remaining features: 71, Removed: wfps_0.05_gfXG_diff12h, RMSE: 0.4616, R²: 0.9523
# Iteration 144: Remaining features: 70, Removed: ts_0.15_gfXG_roll6hmean, RMSE: 0.4584, R²: 0.9528
# Iteration 145: Remaining features: 69, Removed: wfps_0.3_gfXG_lag6h_roll9hmean, RMSE: 0.4598, R²: 0.9524
# Iteration 146: Remaining features: 68, Removed: wfps_0.15_gfXG_diff24h, RMSE: 0.4515, R²: 0.9541
# Iteration 147: Remaining features: 67, Removed: wfps_0.15_gfXG_roll9hmean, RMSE: 0.4547, R²: 0.9537
# Iteration 148: Remaining features: 66, Removed: wfps_0.3_gfXG_lag9h_roll6hmean, RMSE: 0.4513, R²: 0.9545
# Iteration 149: Remaining features: 65, Removed: ts_0.05_gfXG_roll3hmean, RMSE: 0.4593, R²: 0.9528
# Iteration 150: Remaining features: 64, Removed: ta_lag3h_roll3hmean, RMSE: 0.4561, R²: 0.9534
# Iteration 151: Remaining features: 63, Removed: wfps_0.15_gfXG_lag6h_roll6hmean, RMSE: 0.4528, R²: 0.9543
# Iteration 152: Remaining features: 62, Removed: ta_roll3hmean, RMSE: 0.4717, R²: 0.9505
# Iteration 153: Remaining features: 61, Removed: wfps_0.3_gfXG_roll9hmean, RMSE: 0.4591, R²: 0.9528
# Iteration 154: Remaining features: 60, Removed: Reco_U50_reddyproc_lag3h_roll9hsum, RMSE: 0.4594, R²: 0.9529
# Iteration 155: Remaining features: 59, Removed: n_decay_exponential, RMSE: 0.4603, R²: 0.9526
# Iteration 156: Remaining features: 58, Removed: wfps_0.05_gfXG_lag9h_roll9hmean, RMSE: 0.4630, R²: 0.9519
# Iteration 157: Remaining features: 57, Removed: wfps_0.15_gfXG_roll3hmean, RMSE: 0.4544, R²: 0.9538
# Iteration 158: Remaining features: 56, Removed: Reco_U50_reddyproc_roll3hsum, RMSE: 0.4743, R²: 0.9497
# Iteration 159: Remaining features: 55, Removed: prec_lag6h_roll9hsum, RMSE: 0.4686, R²: 0.9511
# Iteration 160: Remaining features: 54, Removed: ts_0.15_gfXG_lag9h_roll6hmean, RMSE: 0.4721, R²: 0.9501
# Iteration 161: Remaining features: 53, Removed: Reco_U50_reddyproc_lag9h_roll3hsum, RMSE: 0.4627, R²: 0.9521
# Iteration 162: Remaining features: 52, Removed: wfps_0.05_gfXG, RMSE: 0.4744, R²: 0.9495
# Iteration 163: Remaining features: 51, Removed: ts_0.15_gfXG_roll9hmean, RMSE: 0.4603, R²: 0.9527
# Iteration 164: Remaining features: 50, Removed: ts_0.3_gfXG_roll3hmean, RMSE: 0.4696, R²: 0.9507
# Iteration 165: Remaining features: 49, Removed: ts_0.3_gfXG_lag9h, RMSE: 0.4583, R²: 0.9530
# Iteration 166: Remaining features: 48, Removed: wfps_0.3_gfXG_lag3h_roll9hmean, RMSE: 0.4647, R²: 0.9516
# Iteration 167: Remaining features: 47, Removed: ts_0.3_gfXG_roll6hmean, RMSE: 0.4592, R²: 0.9529
# Iteration 168: Remaining features: 46, Removed: ppfd, RMSE: 0.4630, R²: 0.9522
# Iteration 169: Remaining features: 45, Removed: Reco_U50_reddyproc_lag3h_roll3hsum, RMSE: 0.4643, R²: 0.9517
# Iteration 170: Remaining features: 44, Removed: prec_lag9h_roll9hsum, RMSE: 0.4627, R²: 0.9521
# Iteration 171: Remaining features: 43, Removed: ts_0.15_gfXG_lag9h_roll3hmean, RMSE: 0.4654, R²: 0.9515
# Iteration 172: Remaining features: 42, Removed: wfps_0.05_gfXG_lag6h_roll3hmean, RMSE: 0.4563, R²: 0.9536
# Iteration 173: Remaining features: 41, Removed: prec_lag3h_roll6hsum, RMSE: 0.4491, R²: 0.9549
# Iteration 174: Remaining features: 40, Removed: wfps_0.3_gfXG_lag9h_roll3hmean, RMSE: 0.4490, R²: 0.9550
# Iteration 175: Remaining features: 39, Removed: wfps_0.15_gfXG_lag9h, RMSE: 0.4580, R²: 0.9532
# Iteration 176: Remaining features: 38, Removed: wfps_0.15_gfXG_lag9h_roll3hmean, RMSE: 0.4505, R²: 0.9547
# Iteration 177: Remaining features: 37, Removed: ts_0.15_gfXG_lag9h_roll9hmean, RMSE: 0.4578, R²: 0.9533
# Iteration 178: Remaining features: 36, Removed: GPP_U50_f_reddyproc_roll3hsum, RMSE: 0.4648, R²: 0.9518
# Iteration 179: Remaining features: 35, Removed: wfps_0.05_gfXG_lag3h_roll6hmean, RMSE: 0.4549, R²: 0.9539
# Iteration 180: Remaining features: 34, Removed: ts_0.3_gfXG_lag9h_roll6hmean, RMSE: 0.4768, R²: 0.9486
# Iteration 181: Remaining features: 33, Removed: wfps_0.3_gfXG_lag3h, RMSE: 0.4855, R²: 0.9470
# Iteration 182: Remaining features: 32, Removed: timesince_fert, RMSE: 0.4692, R²: 0.9506
# Iteration 183: Remaining features: 31, Removed: wfps_0.05_gfXG_lag3h, RMSE: 0.4688, R²: 0.9506
# Iteration 184: Remaining features: 30, Removed: Reco_U50_reddyproc_lag9h_roll9hsum, RMSE: 0.4628, R²: 0.9521
# Iteration 185: Remaining features: 29, Removed: n_decay_logistic, RMSE: 0.4757, R²: 0.9494
# Iteration 186: Remaining features: 28, Removed: ts_0.3_gfXG_roll9hmean, RMSE: 0.4625, R²: 0.9521
# Iteration 187: Remaining features: 27, Removed: wfps_0.3_gfXG_lag3h_roll6hmean, RMSE: 0.4679, R²: 0.9510
# Iteration 188: Remaining features: 26, Removed: ts_0.3_gfXG_lag3h_roll6hmean, RMSE: 0.4552, R²: 0.9535
# Iteration 189: Remaining features: 25, Removed: prec_lag3h_roll9hsum, RMSE: 0.4587, R²: 0.9527
# Iteration 190: Remaining features: 24, Removed: sw_in, RMSE: 0.4549, R²: 0.9535
# Iteration 191: Remaining features: 23, Removed: sowing_timed, RMSE: 0.4653, R²: 0.9513
# Iteration 192: Remaining features: 22, Removed: ts_0.3_gfXG_lag6h_roll6hmean, RMSE: 0.4627, R²: 0.9519
# Iteration 193: Remaining features: 21, Removed: ts_0.3_gfXG_lag3h_roll9hmean, RMSE: 0.4615, R²: 0.9522
# Iteration 194: Remaining features: 20, Removed: ts_0.3_gfXG_lag9h_roll3hmean, RMSE: 0.4594, R²: 0.9526
# Iteration 195: Remaining features: 19, Removed: ts_0.3_gfXG_lag6h_roll3hmean, RMSE: 0.4640, R²: 0.9518
# Iteration 196: Remaining features: 18, Removed: wfps_0.3_gfXG, RMSE: 0.4557, R²: 0.9533
# Iteration 197: Remaining features: 17, Removed: Reco_U50_reddyproc_roll6hsum, RMSE: 0.4683, R²: 0.9511
# Iteration 198: Remaining features: 16, Removed: ts_0.3_gfXG_lag9h_roll9hmean, RMSE: 0.4551, R²: 0.9534
# Iteration 199: Remaining features: 15, Removed: ts_0.3_gfXG_lag6h_roll9hmean, RMSE: 0.4486, R²: 0.9547
# Iteration 200: Remaining features: 14, Removed: wfps_0.15_gfXG_lag3h_roll6hmean, RMSE: 0.4520, R²: 0.9538
# Iteration 201: Remaining features: 13, Removed: wfps_0.15_gfXG_lag9h_roll9hmean, RMSE: 0.4597, R²: 0.9522
# Iteration 202: Remaining features: 12, Removed: wfps_0.05_gfXG_lag9h, RMSE: 0.4495, R²: 0.9544
# Iteration 203: Remaining features: 11, Removed: wfps_0.05_gfXG_roll3hmean, RMSE: 0.4651, R²: 0.9510
# Iteration 204: Remaining features: 10, Removed: wfps_0.15_gfXG_lag6h, RMSE: 0.4887, R²: 0.9456
# Iteration 205: Remaining features: 9, Removed: n_decay_linear, RMSE: 0.4805, R²: 0.9481
# Iteration 206: Remaining features: 8, Removed: wfps_0.15_gfXG_lag6h_roll3hmean, RMSE: 0.4861, R²: 0.9464
# Iteration 207: Remaining features: 7, Removed: id, RMSE: 0.4681, R²: 0.9504
# Iteration 208: Remaining features: 6, Removed: wfps_0.15_gfXG_lag3h_roll3hmean, RMSE: 0.4829, R²: 0.9473
# Iteration 209: Remaining features: 5, Removed: wfps_0.15_gfXG_lag3h_roll9hmean, RMSE: 0.5308, R²: 0.9362
# Iteration 210: Remaining features: 4, Removed: n_decay_timed, RMSE: 0.6499, R²: 0.9030
# Iteration 211: Remaining features: 3, Removed: timesince_sowing, RMSE: 0.6618, R²: 0.8995
# Iteration 212: Remaining features: 2, Removed: n_decay_lognormal, RMSE: 0.6614, R²: 0.8997
# Iteration 213: Remaining features: 1, Removed: timesince_harvest, RMSE: 0.9868, R²: 0.7842
# Best feature set found at iteration 207:
# Selected Features: ['timesince_soil_preparation', 'timesince_harvest', 'timesince_sowing', 'n_decay_lognormal', 'n_decay_timed', 'wfps_0.15_gfXG_lag3h_roll3hmean', 'wfps_0.15_gfXG_lag3h_roll9hmean', 'id']
# Performance - RMSE: 0.4681, R²: 0.9504

# %% [markdown]
# # EXPORT

# %%
filename = 'best_features_' + TARGET_FLUX + '_' + MODEL_TYPE + '.txt'
with open(filename, 'w') as f:
    for item in selected_features:
        f.write(f"{item}\n")

filename = 'ranked_features_' + TARGET_FLUX + '_' + MODEL_TYPE + '.txt'
with open(filename, 'w') as f:
    for item in ranked_features:
        f.write(f"{item}\n")

# %% [markdown]
# # **End of notebook**

# %%
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Finished {dt_string}")
# Out:
# Finished 2025-09-25 11:55:52
