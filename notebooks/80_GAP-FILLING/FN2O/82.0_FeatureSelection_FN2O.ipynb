# %% [markdown]
# # LOAD LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
from datetime import datetime
from sklearn.model_selection import StratifiedShuffleSplit, StratifiedKFold, GridSearchCV, PredefinedSplit
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import root_mean_squared_error, r2_score
from sklearn.inspection import permutation_importance
from sklearn.feature_selection import RFE
from xgboost import XGBRegressor
from diive.core.io.files import load_parquet

# %% [markdown]
# # CONFIGURATION

# %%
START_DATE, END_DATE = '2023-11-08', '2024-07-25' # Wheat
TARGET_FLUX = 'FN2O'
N_FOLDS = 10
MODEL_TYPE = 'XGBoost'  # Options: 'RandomForest' or 'XGBoost'
CROSSVAL_SPLIT = 'time_blocks_eliza' # options: 'shuffle' or 'kfold' or 'custom_time_blocks' or 'time_blocks_eliza'
PARCEL_CERTAIN = True
LOG_TRANSFORM = True
ADD_ID = True
UNDERSAMPLE = True
PERMUTATION_SEL = False
RFE_SEL = True

# %% [markdown]
# # LOAD DATA

# %%
data_main = fluxes = load_parquet(filepath=r"../81.1_GapFillingDataset.parquet")
data_main = data_main.loc[START_DATE:END_DATE].copy()

# Add an id column to account for the proximity of values as the timestamp is continuous without gaps
if ADD_ID:
    data_main['id'] = range(0, len(data_main))

data_main
# Out:
# Loaded .parquet file ../81.1_GapFillingDataset.parquet (0.276 seconds).
#     --> Detected time resolution of <30 * Minutes> / 30min
#                      NEE_L3.3_CUT_50_QCF  FN2O_L3.3_CUT_50_QCF  FCH4_L3.3_CUT_50_QCF  NEE_L3.3_CUT_50_QCF0  FN2O_L3.3_CUT_50_QCF0  FCH4_L3.3_CUT_50_QCF0  NEE_U50_f_reddyproc  GPP_U50_f_reddyproc  Reco_U50_reddyproc parcel parcel_certainty  prec         ta  timesince_prec       vpd  ...  ts_0.15_gfXG_diff12h  ts_0.15_gfXG_diff24h  ts_0.3_gfXG_diff6h  ts_0.3_gfXG_diff12h  ts_0.3_gfXG_diff24h  wfps_0.05_gfXG_diff6h  wfps_0.05_gfXG_diff12h  wfps_0.05_gfXG_diff24h  wfps_0.15_gfXG_diff6h  wfps_0.15_gfXG_diff12h  wfps_0.15_gfXG_diff24h  wfps_0.3_gfXG_diff6h  wfps_0.3_gfXG_diff12h  wfps_0.3_gfXG_diff24h     id
# TIMESTAMP_MIDDLE                                                                                                                                                                                                                                                                           ...
# 2023-11-08 00:15:00                  NaN             -0.111997             -3.231648                   NaN                    NaN              -3.231648             1.991226            -0.238835            1.752390      B          certain   0.0   5.333333            12.0  0.180179  ...             -1.116706             -1.152150           -0.275176            -0.379151             2.956382              -1.564360                0.573172               -0.047840              -0.181710               -0.177446                0.052573             -1.360142              -0.071378               0.477293      0
# 2023-11-08 00:45:00                  NaN              0.100302                   NaN                   NaN               0.100302                    NaN             2.035776            -0.203400            1.832376      B          certain   0.0   5.966667            13.0  0.210078  ...             -1.202539             -1.002316           -0.315639            -0.100172             2.819366              -3.022171                0.720981               -0.202111              -0.048345                0.008988                0.015635             -1.939471               0.000852               0.241896      1
# 2023-11-08 01:15:00                  NaN              0.239428                   NaN                   NaN               0.239428                    NaN             2.026159            -0.210755            1.815404      B          certain   0.0   5.833333            14.0  0.209377  ...             -1.423575             -1.251268            0.154263             0.054827             2.845686              -1.730258                0.304878                0.755972              -0.137978                0.079340                0.129646             -0.687567               0.201061               0.512755      2
# 2023-11-08 01:45:00                  NaN             -0.184917              6.746138                   NaN                    NaN                    NaN             2.026159            -0.206519            1.819640      B          certain   0.0   5.866667            15.0  0.212335  ...             -1.456775             -1.194985            0.190084             0.205121             2.216312              -1.685342                0.385222                0.331593              -0.220338               -0.022307                0.288816             -0.600509               0.215442               0.568651      3
# 2023-11-08 02:15:00                  NaN              0.358358              3.168362                   NaN               0.358358               3.168362             2.025592            -0.218648            1.806944      B          certain   0.0   5.766667            16.0  0.210251  ...             -1.730865             -1.054997            0.243881             0.243286             1.087768              -1.500100                0.629110                0.868842              -0.175981               -0.027153                0.167790             -0.600174               0.027040               0.576383      4
# ...                                  ...                   ...                   ...                   ...                    ...                    ...                  ...                  ...                 ...    ...              ...   ...        ...             ...       ...  ...                   ...                   ...                 ...                  ...                  ...                    ...                     ...                     ...                    ...                     ...                     ...                   ...                    ...                    ...    ...
# 2024-07-25 21:45:00                  NaN                   NaN                   NaN                   NaN                    NaN                    NaN             6.509221            -1.562339            4.946882   None             None   0.0  16.166667           128.0  0.246013  ...              1.979258              0.117887            0.470140             1.934095             0.069588              -0.781542               -0.944345               -0.828950              -0.099631                0.205294               -0.326433             -0.285875               0.167037              -0.173701  12523
# 2024-07-25 22:15:00                  NaN                   NaN                   NaN                   NaN                    NaN                    NaN             6.509221            -1.656828            4.852393   None             None   0.0  15.766667           129.0  0.218872  ...              1.702703              0.001131            0.240362             1.779158            -0.057751              -0.904521               -1.299068               -1.184607              -0.106046                0.163649               -0.343612             -0.287530              -0.037435              -0.212412  12524
# 2024-07-25 22:45:00                  NaN                   NaN                   NaN                   NaN                    NaN                    NaN             6.509221            -1.671307            4.837914   None             None   0.0  15.700000           130.0  0.207221  ...              1.272358             -0.123926            0.233171             1.737272            -0.048307              -1.044708               -1.119899               -1.157502              -0.137013                0.089801               -0.460830             -0.300689               0.009702              -0.200432  12525
# 2024-07-25 23:15:00                  NaN                   NaN                   NaN                   NaN                    NaN                    NaN             6.342254            -1.550607            4.791647   None             None   0.0  15.500000           131.0  0.184005  ...              1.099369             -0.090977            0.002081             1.504118            -0.091599              -1.306658               -1.568278               -1.012367              -0.315724               -0.134599               -0.519220             -0.196787               0.059932              -0.135882  12526
# 2024-07-25 23:45:00                  NaN                   NaN                   NaN                   NaN                    NaN                    NaN             6.813999            -2.084303            4.729695   None             None   0.0  15.233333           132.0  0.162965  ...              0.860147             -0.302116           -0.078962             1.452023            -0.197208              -0.815680               -1.131087               -0.492910              -0.082602                0.041554               -0.284454             -0.181011               0.116357              -0.113047  12527
#
# [12528 rows x 232 columns]

# %% [markdown]
# # CLEAN DATA

# %%
TARGET = f'{TARGET_FLUX}_L3.3_CUT_50_QCF0'
print(f'The target variable is {TARGET}')

mean_nan_size = (
    data_main[TARGET]
    .isna()
    .ne(data_main[TARGET].isna().shift())
    .cumsum()
    .where(data_main[TARGET].isna())
    .dropna()
    .value_counts()
    .mean()
)
print("\nMean size of consecutive NaNs in the target variable:", mean_nan_size)

# Remove NAs
data = data_main[data_main[TARGET].notna()].copy()

# Keep only data where we are sure about parcel attribution
if PARCEL_CERTAIN:
    data = data[data['parcel_certainty'] == 'certain'].copy()
    print('\nKeeping only data when we are highly confident on the parcel attribution')

# Remove some variables that cannot mechanistically be related to N2O flux or hard to explain 
# prefix = ('flux_reco', 'flux_h', 'flux_le', 'lai', 'canopy_height', 'sw', 'flux_ch4', 'flux_nee', 'pa', 'rh', 'fert', 'harvest', 'soil_preparation', 'sowing', 'nitrogen_fert', 'ta', 'timesince_sowing', 'crop_n')
# inside = ('0.5')
# to_drop = [c for c in data.columns if c.startswith(prefix) or inside in c]
# data.drop(columns=to_drop, inplace=True)
# print(f"Dropped {len(to_drop)} columns considered not to be relevant for the target based on knowledge: {to_drop}")

# Keep only variables of the chosen categories
prefix = ('wfps', 'ts', 'prec', 'GPP', 'n_decay_timed', 'timesince_fert', TARGET)
to_keep = [c for c in data.columns if c.startswith(prefix)]
data = data[to_keep].copy()
to_remove = [c for c in data.columns if 'parcelA' in c or 'parcelB' in c]
data.drop(columns=to_remove, inplace=True)

# Remove any flux variable with target flux except for the target itself
to_drop = [col for col in data.columns if TARGET_FLUX in col]
# Leave the target!
to_drop.remove(TARGET)
data.drop(columns=to_drop, inplace=True)

def clean_data(df, threshold=0.05):
    """Remove columns with too many missing values and non-numeric columns."""
    dropped_missing = df.columns[df.isna().mean() > threshold].tolist()
    df = df.drop(columns=dropped_missing)
    dropped_non_numeric = df.select_dtypes(exclude=[np.number]).columns.tolist()
    df = df.select_dtypes(include=[np.number])
    print(f"\nDropped {len(dropped_missing)} due to missing values: {dropped_missing}")
    print(f"Dropped {len(dropped_non_numeric)} non-numeric columns: {dropped_non_numeric}")
    
    return df

data = clean_data(data)

data
# Out:
# The target variable is FN2O_L3.3_CUT_50_QCF0
#
# Mean size of consecutive NaNs in the target variable: 4.583804143126177
#
# Keeping only data when we are highly confident on the parcel attribution
#
# Dropped 0 due to missing values: []
# Dropped 0 non-numeric columns: []
#                      FN2O_L3.3_CUT_50_QCF0  GPP_U50_f_reddyproc  prec  ts_0.05_gfXG  ts_0.15_gfXG  ts_0.3_gfXG  wfps_0.05_gfXG  wfps_0.15_gfXG  wfps_0.3_gfXG  n_decay_timed  timesince_fert  GPP_U50_f_reddyproc_lag3h  GPP_U50_f_reddyproc_lag6h  GPP_U50_f_reddyproc_lag9h  prec_lag3h  ...  ts_0.15_gfXG_diff6h  ts_0.15_gfXG_diff12h  ts_0.15_gfXG_diff24h  ts_0.3_gfXG_diff6h  ts_0.3_gfXG_diff12h  ts_0.3_gfXG_diff24h  wfps_0.05_gfXG_diff6h  wfps_0.05_gfXG_diff12h  wfps_0.05_gfXG_diff24h  wfps_0.15_gfXG_diff6h  wfps_0.15_gfXG_diff12h  wfps_0.15_gfXG_diff24h  wfps_0.3_gfXG_diff6h  wfps_0.3_gfXG_diff12h  wfps_0.3_gfXG_diff24h
# TIMESTAMP_MIDDLE                                                                                                                                                                                                                                                                           ...
# 2023-11-08 00:45:00               0.100302            -0.203400   0.0      6.817496      9.855426    10.933558       38.511337       51.889339      35.429823           29.0            22.0                  -0.207650                  -0.207284                   0.608764         0.0  ...            -1.413669             -1.202539             -1.002316           -0.315639            -0.100172             2.819366              -3.022171                0.720981               -0.202111              -0.048345                0.008988                0.015635             -1.939471               0.000852               0.241896
# 2023-11-08 01:15:00               0.239428            -0.210755   0.0      6.969578      9.790032    10.941941       38.346531       51.961689      35.631750           29.0            22.0                  -0.214772                  -0.217419                   0.379030         0.0  ...            -1.482971             -1.423575             -1.251268            0.154263             0.054827             2.845686              -1.730258                0.304878                0.755972              -0.137978                0.079340                0.129646             -0.687567               0.201061               0.512755
# 2023-11-08 02:15:00               0.358358            -0.218648   0.0      7.089032      9.802778    11.114241       38.446839       51.881405      35.604578           29.0            22.0                  -0.230492                  -0.202999                  -0.291887         0.0  ...            -1.522183             -1.730865             -1.054997            0.243881             0.243286             1.087768              -1.500100                0.629110                0.868842              -0.175981               -0.027153                0.167790             -0.600174               0.027040               0.576383
# 2023-11-08 03:15:00               0.070120            -0.230492   0.0      7.258470      9.776045    10.794777       38.412783       51.874562      35.653820           29.0            22.0                  -0.238835                  -0.213156                  -0.211537         0.0  ...            -1.514255             -1.743717             -1.250376           -0.069672             0.010304             0.609105              -1.514331                0.425002                1.042137              -0.005165               -0.065745                0.055501              0.100861               0.057352               0.449444
# 2023-11-08 04:15:00              -0.545573            -0.152503   0.0      7.059120     10.027685    10.725005       38.409004       51.873226      35.993931           29.0            22.0                  -0.210755                  -0.214772                  -0.217419         0.0  ...            -1.212816             -1.319282             -0.813456           -0.114923            -0.589170             0.650526              -1.214557                0.525693                1.072204               0.251217                0.064532                0.108497              0.323842               0.325964               0.776480
# ...                                    ...                  ...   ...           ...           ...          ...             ...             ...            ...            ...             ...                        ...                        ...                        ...         ...  ...                  ...                   ...                   ...                 ...                  ...                  ...                    ...                     ...                     ...                    ...                     ...                     ...                   ...                    ...                    ...
# 2024-07-22 17:15:00               0.430606             6.524246   0.0     22.343701     21.290741    20.215554       42.495615       51.166678      33.326382            0.0            30.0                  12.252478                   4.110276                   0.898030         0.0  ...             0.690741              0.290741             -1.135556            0.016665            -0.326669            -0.350742              -1.101004                6.425403                5.622711              -1.274613                2.731379                2.272492              0.122500               2.128122               1.836714
# 2024-07-22 18:15:00               0.311525             5.767465   0.0     22.226295     21.400000    20.271852       42.389464       51.100761      33.311153            0.0            30.0                   9.586085                   6.985917                   3.818548         0.0  ...             0.800000              0.500000             -1.107407            0.106665            -0.211111            -0.426296              -0.868719                6.232268                5.626720              -0.981354                2.671377                2.236652             -0.169361               2.142724               1.837053
# 2024-07-23 05:15:00               0.314246             0.598910   0.0     19.620371     20.544445    20.154817       41.628814       50.629021      33.107407            0.0            30.0                  -0.031186                   0.232035                   0.235788         0.0  ...            -0.655555             -0.746296             -0.455555           -0.244443            -0.060737            -0.387406              -0.335437               -0.866801                5.558602              -0.205493               -0.537657                2.193722             -0.092647              -0.218976               1.909146
# 2024-07-23 18:15:00               0.575519             3.142451   0.0     23.331479     22.000000    20.398148       40.732419       50.322159      32.667757            0.0            30.0                  12.908592                  14.955685                  10.308966         0.0  ...             1.471852              1.591482              0.600000            0.577039             0.306296             0.126296              -0.615398               -0.838254               -1.657045              -0.098310               -0.274967               -0.778602             -0.129967              -0.460942              -0.643396
# 2024-07-23 20:15:00               0.586950             1.471090   0.0     22.421481     22.000000    20.565926       40.578706       50.275204      32.666013            0.0            30.0                   6.451365                  11.711217                  13.672820         0.0  ...             0.852222              1.735926              0.600000            0.655556             0.622224             0.198150              -0.553513               -0.938438               -1.631175              -0.131180               -0.291483               -0.705238             -0.078957              -0.378195              -0.613143
#
# [3895 rows x 149 columns]

# %% [markdown]
# # IMBALANCE HANDLING

# %% [markdown]
# ## UNDER SAMPLING

# %%
if UNDERSAMPLE:
    quantile_cutoff = 0.8
    cutoff_value = data[TARGET].quantile(quantile_cutoff)
    print(f'Undersampling target data below: {cutoff_value}')
    # Split and undersample
    upper = data[data[TARGET] > cutoff_value]
    lower = data[data[TARGET] <= cutoff_value]
    # Undersample
    lower_sampled = lower.sample(frac=0.5, random_state=42)
    # Combine
    data = pd.concat([upper, lower_sampled]).sample(frac=1, random_state=42)
    # Resort data
    data = data.sort_index().reset_index(drop=False)  # keep the timestamp as a column
    data = data.set_index('TIMESTAMP_MIDDLE')    # and set it back as index if needed
    # Plot
    data[TARGET].plot(x_compat=True, style='.')
    plt.show()
# Out:
# Undersampling target data below: 0.311087692

# %% [markdown]
# ## LOG TRANSFORMATION

# %%
min_value = data[TARGET].min()

def log_transform(x):
    return np.log1p(x - min_value) if min_value < 0 else np.log1p(x)

def inverse_log_transform(x):
    return np.expm1(x) + min_value if min_value < 0 else np.expm1(x)

if LOG_TRANSFORM:
    data[TARGET] = log_transform(data[TARGET])

# Show histogram of TARGET
plt.hist(data[TARGET], bins=20)
plt.xlabel(TARGET)
plt.show()

# Show timeseries
data[TARGET].plot(x_compat=True, style='.');

data
# Out:
#                      FN2O_L3.3_CUT_50_QCF0  GPP_U50_f_reddyproc  prec  ts_0.05_gfXG  ts_0.15_gfXG  ts_0.3_gfXG  wfps_0.05_gfXG  wfps_0.15_gfXG  wfps_0.3_gfXG  n_decay_timed  timesince_fert  GPP_U50_f_reddyproc_lag3h  GPP_U50_f_reddyproc_lag6h  GPP_U50_f_reddyproc_lag9h  prec_lag3h  ...  ts_0.15_gfXG_diff6h  ts_0.15_gfXG_diff12h  ts_0.15_gfXG_diff24h  ts_0.3_gfXG_diff6h  ts_0.3_gfXG_diff12h  ts_0.3_gfXG_diff24h  wfps_0.05_gfXG_diff6h  wfps_0.05_gfXG_diff12h  wfps_0.05_gfXG_diff24h  wfps_0.15_gfXG_diff6h  wfps_0.15_gfXG_diff12h  wfps_0.15_gfXG_diff24h  wfps_0.3_gfXG_diff6h  wfps_0.3_gfXG_diff12h  wfps_0.3_gfXG_diff24h
# TIMESTAMP_MIDDLE                                                                                                                                                                                                                                                                           ...
# 2023-11-08 00:45:00               0.772865            -0.203400   0.0      6.817496      9.855426    10.933558       38.511337       51.889339      35.429823           29.0            22.0                  -0.207650                  -0.207284                   0.608764         0.0  ...            -1.413669             -1.202539             -1.002316           -0.315639            -0.100172             2.819366              -3.022171                0.720981               -0.202111              -0.048345                0.008988                0.015635             -1.939471               0.000852               0.241896
# 2023-11-08 02:15:00               0.885426            -0.218648   0.0      7.089032      9.802778    11.114241       38.446839       51.881405      35.604578           29.0            22.0                  -0.230492                  -0.202999                  -0.291887         0.0  ...            -1.522183             -1.730865             -1.054997            0.243881             0.243286             1.087768              -1.500100                0.629110                0.868842              -0.175981               -0.027153                0.167790             -0.600174               0.027040               0.576383
# 2023-11-08 11:45:00               0.755965             1.610370   0.0      8.219166      9.405691     9.212877       38.417302       51.938420      36.011344           29.0            22.0                   0.896517                  -0.106382                  -0.218987         0.0  ...            -0.508040             -1.108148             -1.402914           -1.422082            -2.595901            -2.010428              -0.106256               -0.399017                0.616091               0.008816                0.110672               -0.001470              0.017809               0.946879               0.569824
# 2023-11-08 12:15:00               0.873966             1.664430   0.0      7.895454      9.651937     8.696554       38.497245       51.994515      36.126531           29.0            22.0                   1.450181                  -0.108189                  -0.230492         0.0  ...            -0.216370             -0.163406             -1.280112           -1.867862            -2.211858            -2.591009              -0.024149                0.141656                0.714828               0.085479                0.206670                0.029224              0.208761               0.690103               0.618725
# 2023-11-08 12:45:00               0.825594             2.825652   0.0      8.830851      9.612379     8.798609       38.281806       51.965867      36.214424           29.0            23.0                   1.264643                  -0.086391                  -0.231495         0.0  ...             0.731183             -0.243047             -1.445586           -1.761413            -2.134949            -2.235121              -0.320615               -0.229530                0.491451              -0.004178                0.076528                0.085516              0.296654               0.784602               0.785454
# ...                                    ...                  ...   ...           ...           ...          ...             ...             ...            ...            ...             ...                        ...                        ...                        ...         ...  ...                  ...                   ...                   ...                 ...                  ...                  ...                    ...                     ...                     ...                    ...                     ...                     ...                   ...                    ...                    ...
# 2024-07-22 17:15:00               0.914796             6.524246   0.0     22.343701     21.290741    20.215554       42.495615       51.166678      33.326382            0.0            30.0                  12.252478                   4.110276                   0.898030         0.0  ...             0.690741              0.290741             -1.135556            0.016665            -0.326669            -0.350742              -1.101004                6.425403                5.622711              -1.274613                2.731379                2.272492              0.122500               2.128122               1.836714
# 2024-07-22 18:15:00               0.865917             5.767465   0.0     22.226295     21.400000    20.271852       42.389464       51.100761      33.311153            0.0            30.0                   9.586085                   6.985917                   3.818548         0.0  ...             0.800000              0.500000             -1.107407            0.106665            -0.211111            -0.426296              -0.868719                6.232268                5.626720              -0.981354                2.671377                2.236652             -0.169361               2.142724               1.837053
# 2024-07-23 05:15:00               0.867061             0.598910   0.0     19.620371     20.544445    20.154817       41.628814       50.629021      33.107407            0.0            30.0                  -0.031186                   0.232035                   0.235788         0.0  ...            -0.655555             -0.746296             -0.455555           -0.244443            -0.060737            -0.387406              -0.335437               -0.866801                5.558602              -0.205493               -0.537657                2.193722             -0.092647              -0.218976               1.909146
# 2024-07-23 18:15:00               0.971225             3.142451   0.0     23.331479     22.000000    20.398148       40.732419       50.322159      32.667757            0.0            30.0                  12.908592                  14.955685                  10.308966         0.0  ...             1.471852              1.591482              0.600000            0.577039             0.306296             0.126296              -0.615398               -0.838254               -1.657045              -0.098310               -0.274967               -0.778602             -0.129967              -0.460942              -0.643396
# 2024-07-23 20:15:00               0.975544             1.471090   0.0     22.421481     22.000000    20.565926       40.578706       50.275204      32.666013            0.0            30.0                   6.451365                  11.711217                  13.672820         0.0  ...             0.852222              1.735926              0.600000            0.655556             0.622224             0.198150              -0.553513               -0.938438               -1.631175              -0.131180               -0.291483               -0.705238             -0.078957              -0.378195              -0.613143
#
# [2337 rows x 149 columns]

# %% [markdown]
# # CROSS-VAL SPLITS

# %% [markdown]
# Using stratified approach based on the target variable

# %%
def create_splits(X, y, n_folds, test_size=0.2, random_state=42, n_bins=5):
    """Creates train-test splits using StratifiedShuffleSplit or StratifiedKFold with equal-width binning."""
    
    # Use pd.cut to create equal-width bins (avoids empty bins issue)
    y_binned = pd.cut(y, bins=n_bins, labels=False, include_lowest=True)

    # Select method for stratified splitting
    if CROSSVAL_SPLIT == "shuffle":
        splitter = StratifiedShuffleSplit(n_splits=n_folds, test_size=test_size, random_state=random_state)
    elif CROSSVAL_SPLIT == "kfold":
        splitter = StratifiedKFold(n_splits=n_folds, shuffle=False)

    # Generate train-test splits
    splits = [(train_idx, test_idx) for train_idx, test_idx in splitter.split(X, y_binned)]

    return splits

if CROSSVAL_SPLIT == 'time_blocks_eliza':
    def create_splits(X, y, n_folds, split=0.2, mean_block=24, min_block=1, random_state=42): # you can set mean block to mean_nan_size
        """Generates multiple train-test index splits using block-based cross-validation by varying the random seed."""
        splits = []
        total_test = round(len(X) * split)
        n_blocks = round(total_test/mean_block)

        if mean_block < min_block:
            raise ValueError("Min block size is too large for the number of blocks.")

        for fold in range(n_folds):
            np.random.seed(random_state + fold)  # Change seed for each fold
            
            tt = np.zeros(len(X))  # Array to store train-test assignments

            # Generate random block sizes with normal variation
            blocks = np.array([max(min_block, mean_block + round(v)) 
                            for v in np.random.normal(0, mean_block / 10, n_blocks)])

            # Randomly shuffle the starting positions of test blocks
            available_positions = np.arange(len(X))  # Possible start positions
            np.random.shuffle(available_positions)   # Shuffle them

            # Assign blocks sequentially based on shuffled positions
            assigned = set()
            for b in blocks:
                if len(assigned) >= total_test:
                    break
                # Pick a random starting position
                istart = np.random.choice(available_positions)
                iend = min(istart + int(b), len(X))

                # Ensure blocks don't overlap significantly
                assigned.update(range(istart, iend))
                tt[istart:iend] = 1

            train_idx = np.where(tt == 0)[0]
            test_idx = np.where(tt == 1)[0]
            
            splits.append((train_idx, test_idx))

        return splits
    
if CROSSVAL_SPLIT == 'custom_time_blocks':
    def create_splits(X, y, n_folds=5, test_fraction=0.2, block_duration='1D',
                    min_gap='6D', buffer_gap='1D', seed=None):
        """
        Time-block CV with buffer and min_gap enforcement, allowing partial blocks to match test_fraction.
        """
        if seed is not None:
            np.random.seed(seed)

        total_rows = len(X)
        total_test_target = int(total_rows * test_fraction)
        all_times = X.index
        block_dur = pd.to_timedelta(block_duration)
        min_gap_dur = pd.to_timedelta(min_gap)
        buffer_gap_dur = pd.to_timedelta(buffer_gap)

        # Generate all possible block start times
        possible_starts = all_times[(all_times + block_dur) <= all_times[-1]]
        splits = []

        for fold in range(n_folds):
            test_indices = set()
            buffer_indices = set()
            selected_blocks = []

            shuffled_starts = np.random.permutation(possible_starts)

            for start_time in shuffled_starts:
                end_time = start_time + block_dur
                buffer_start = start_time - buffer_gap_dur
                buffer_end = end_time + buffer_gap_dur

                # Enforce min_gap between selected test blocks
                if any(abs(pd.Timedelta(start_time - sel).total_seconds()) < min_gap_dur.total_seconds()
                    for sel in selected_blocks):
                    continue

                block_mask = (all_times >= start_time) & (all_times < end_time)
                buffer_mask = (all_times >= buffer_start) & (all_times < buffer_end)

                block_idx = np.where(block_mask)[0]
                buffer_idx = np.where(buffer_mask)[0]

                if len(block_idx) == 0:
                    continue

                # Allow trimming final block if needed
                remaining = total_test_target - len(test_indices)
                if remaining <= 0:
                    break
                if len(block_idx) > remaining:
                    block_idx = block_idx[:remaining]

                # Check again for overlap with buffer
                if any(i in buffer_indices for i in block_idx):
                    continue

                test_indices.update(block_idx)
                buffer_indices.update(buffer_idx)
                selected_blocks.append(start_time)

                if len(test_indices) >= total_test_target:
                    break

            train_indices = sorted(set(range(total_rows)) - test_indices - buffer_indices)
            splits.append((np.array(train_indices), np.array(sorted(test_indices))))

        return splits

X = data.drop(columns=TARGET)
y = data[TARGET]
# Create the splits using StratifiedShuffleSplit
cross_val_splits = create_splits(X, y, n_folds=N_FOLDS)


# --- PLOT TRAIN-TEST SPLITS ---
n_rows = math.ceil(N_FOLDS / 2)  # Ensure enough rows for all splits
fig, axes = plt.subplots(n_rows, 2, figsize=(14, 8))
axes = axes.flatten()  # Flatten the axes array to make iteration easier

for i, (train_idx, test_idx) in enumerate(cross_val_splits):
    train_idx_mapped = X.iloc[train_idx].index
    test_idx_mapped = X.iloc[test_idx].index

    # Plot train and test points
    axes[i].plot(y.loc[train_idx_mapped].index, y.loc[train_idx_mapped], '.', label='Train', color="blue")
    axes[i].plot(y.loc[test_idx_mapped].index, y.loc[test_idx_mapped], 'x', label='Test', color="red")
    
    axes[i].set_title(f"Split {i + 1} ({CROSSVAL_SPLIT})")
    axes[i].legend()

# Hide unused subplots if n_folds is odd
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# # FEATURE SELECTION

# %% [markdown]
# ## Permutation importance

# %%
N_REPEATS = 5
N_RANDOMS = 10 
def permutation_importance_selection(X, y, n_repeats=N_REPEATS, n_randoms=N_RANDOMS):
    iteration = 0

    # Generate random features ONCE and keep them throughout the iterations
    np.random.seed(42)  # Ensures reproducibility
    for i in range(n_randoms):
        X[f'random_{i}'] = np.random.permutation(len(X))

    while True:
        iteration += 1
        print(f"Iteration {iteration}: Starting with {X.shape[1] - n_randoms} features")

        model = RandomForestRegressor(n_estimators=100, min_samples_split=10, min_samples_leaf=5, random_state=42, n_jobs=-1) \
            if MODEL_TYPE == 'RandomForest' else XGBRegressor(n_estimators=100, random_state=42, n_jobs=-1)
        importance_scores, rmse_scores, r2_scores = [], [], []

        for train_idx, test_idx in cross_val_splits:
            X_train, y_train, X_test, y_test = X.iloc[train_idx], y.iloc[train_idx], X.iloc[test_idx], y.iloc[test_idx]
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)

            # Invert the transformation if it was applied to calculate the performance with the original scale
            if LOG_TRANSFORM:
                y_test, y_pred = inverse_log_transform(y_test), inverse_log_transform(y_pred)

            perm_importance = permutation_importance(model, X_test, y_test, n_repeats=n_repeats, random_state=42, n_jobs=-1)
            importance_scores.append(perm_importance.importances_mean)
            rmse_scores.append(root_mean_squared_error(y_test, y_pred))
            r2_scores.append(r2_score(y_test, y_pred))

        mean_importance = np.mean(importance_scores, axis=0)
        threshold = np.mean(mean_importance[-n_randoms:])  # Use average of random features as threshold
        
        to_remove = [col for col in X.columns if mean_importance[X.columns.get_loc(col)] < threshold and not col.startswith('random_')]
        to_keep = [col for col in X.columns if col not in to_remove]
        print(f"Iteration {iteration}: Removed {len(to_remove)} features, RMSE: {np.mean(rmse_scores):.4f}, R²: {np.mean(r2_scores):.4f}")
        
        if len(to_remove) == 0:
            break  # Stop when no features are removed

        X = X[to_keep].copy()

    # Remove random features from final selection
    to_keep = [col for col in to_keep if not col.startswith('random_')]
    return to_keep


if PERMUTATION_SEL:
    to_keep = permutation_importance_selection(data.drop(columns=[TARGET]), data[TARGET])
    data = data[to_keep + [TARGET]]
    to_keep

# %% [markdown]
# ## Recursive feature elimination

# %%
def rfe_selection(X, y, cross_val_splits):
    performance = []
    iteration = 0
    features = list(X.columns)
    feature_removal_order = []  # Store removed features and their iteration index

    while len(features) > 1:
        iteration += 1
        rmse_scores, r2_scores, importances = [], [], []

        for train_idx, test_idx in cross_val_splits:
            X_train, y_train, X_test, y_test = X[features].iloc[train_idx], y.iloc[train_idx], X[features].iloc[test_idx], y.iloc[test_idx]
            model = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1) if MODEL_TYPE == 'RandomForest' else XGBRegressor(n_estimators=100, random_state=42, n_jobs=-1)
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)
            
            # Invert the transformation if it was applied to calculate the performance with the original scale
            if LOG_TRANSFORM:
                y_test, y_pred = inverse_log_transform(y_test), inverse_log_transform(y_pred)
            
            rmse_scores.append(root_mean_squared_error(y_test, y_pred))
            r2_scores.append(r2_score(y_test, y_pred))
            importances.append(model.feature_importances_)

        mean_rmse = np.mean(rmse_scores)
        mean_r2 = np.mean(r2_scores)
        performance.append((features.copy(), mean_rmse, mean_r2))

        mean_importances = np.mean(importances, axis=0)
        least_important_index = np.argmin(mean_importances)
        least_important_feature = features.pop(least_important_index)

        # Store the removed feature with its iteration index
        feature_removal_order.append((least_important_feature, iteration))

        print(f"Iteration {iteration}: Remaining features: {len(features)}, Removed: {least_important_feature}, RMSE: {mean_rmse:.4f}, R²: {mean_r2:.4f}")

    # Extract RMSE and R² values
    rmse_values = [score[1] for score in performance]
    r2_values = [score[2] for score in performance]

    # Plot RMSE and R² over iterations
    fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)
    axs[0].plot(range(len(performance)), rmse_values, label="Cross-validated RMSE")
    axs[0].set_ylabel("RMSE")
    axs[0].legend()

    axs[1].plot(range(len(performance)), r2_values, label="Cross-validated R²", color="orange")
    axs[1].set_xlabel("Iteration")
    axs[1].set_ylabel("R²")
    axs[1].legend()

    plt.tight_layout()
    plt.show()

    # Select best feature set by minimizing both R² and RMSE and penlizing larger feature sets
    # Normalize RMSE and R²
    norm_rmse = (np.array(rmse_values) - min(rmse_values)) / (max(rmse_values) - min(rmse_values))
    norm_r2 = (np.array(r2_values) - min(r2_values)) / (max(r2_values) - min(r2_values))
    # Set weights for normalized metrics
    w_rmse, w_r2, w_penalty = 0.5, 0.5, 0.01  # Adjust w_penalty as needed
    # Calculate composite scores with normalized metrics and feature count penalty
    composite_scores = [
        (performance[i][0], # Features
         i + 1, # Iteration number
        w_rmse * norm_rmse[i] + w_r2 * (1 - norm_r2[i]) + w_penalty * len(performance[i][0])  # Composite score
        )  
        for i in range(len(performance))
    ]

    # Find the feature subset with the best (lowest) composite score
    best_features, best_iteration, _ = min(composite_scores, key=lambda x: x[2])

    # Add the final remaining feature
    feature_removal_order.append((features[0], iteration + 1))

    # Rank features based on removal order
    feature_ranking = [feature for feature, _ in sorted(feature_removal_order, key=lambda x: x[1], reverse=True)]

    # Print the best feature set details
    print(f"\nBest feature set found at iteration {best_iteration}:")
    print(f"Selected Features: {best_features}")
    print(f"Performance - RMSE: {rmse_values[best_iteration-1]:.4f}, R²: {r2_values[best_iteration-1]:.4f}")

    return best_features, feature_ranking

if RFE_SEL:
    selected_features, ranked_features = rfe_selection(data.drop(columns=[TARGET]), data[TARGET], cross_val_splits= cross_val_splits)
    # Update the main dataframe
    data = data[selected_features + [TARGET]]
# Out:
# Iteration 1: Remaining features: 147, Removed: prec, RMSE: 0.3474, R²: 0.3341
# Iteration 2: Remaining features: 146, Removed: ts_0.15_gfXG, RMSE: 0.3453, R²: 0.3430
# Iteration 3: Remaining features: 145, Removed: prec_lag3h, RMSE: 0.3488, R²: 0.3292
# Iteration 4: Remaining features: 144, Removed: prec_lag9h, RMSE: 0.3499, R²: 0.3244
# Iteration 5: Remaining features: 143, Removed: wfps_0.15_gfXG, RMSE: 0.3462, R²: 0.3404
# Iteration 6: Remaining features: 142, Removed: GPP_U50_f_reddyproc_lag6h, RMSE: 0.3477, R²: 0.3342
# Iteration 7: Remaining features: 141, Removed: ts_0.05_gfXG_lag9h_roll3hmean, RMSE: 0.3502, R²: 0.3254
# Iteration 8: Remaining features: 140, Removed: GPP_U50_f_reddyproc_lag9h, RMSE: 0.3483, R²: 0.3318
# Iteration 9: Remaining features: 139, Removed: GPP_U50_f_reddyproc_lag3h, RMSE: 0.3464, R²: 0.3398
# Iteration 10: Remaining features: 138, Removed: ts_0.05_gfXG_lag3h, RMSE: 0.3504, R²: 0.3228
# Iteration 11: Remaining features: 137, Removed: ts_0.05_gfXG_lag6h, RMSE: 0.3509, R²: 0.3211
# Iteration 12: Remaining features: 136, Removed: wfps_0.3_gfXG, RMSE: 0.3484, R²: 0.3324
# Iteration 13: Remaining features: 135, Removed: ts_0.05_gfXG_lag3h_roll9hmean, RMSE: 0.3516, R²: 0.3191
# Iteration 14: Remaining features: 134, Removed: ts_0.05_gfXG_lag9h, RMSE: 0.3502, R²: 0.3236
# Iteration 15: Remaining features: 133, Removed: ts_0.05_gfXG, RMSE: 0.3523, R²: 0.3157
# Iteration 16: Remaining features: 132, Removed: ts_0.3_gfXG, RMSE: 0.3504, R²: 0.3201
# Iteration 17: Remaining features: 131, Removed: wfps_0.05_gfXG, RMSE: 0.3463, R²: 0.3383
# Iteration 18: Remaining features: 130, Removed: ts_0.15_gfXG_lag3h, RMSE: 0.3476, R²: 0.3336
# Iteration 19: Remaining features: 129, Removed: ts_0.15_gfXG_lag6h, RMSE: 0.3475, R²: 0.3350
# Iteration 20: Remaining features: 128, Removed: ts_0.15_gfXG_lag9h, RMSE: 0.3501, R²: 0.3244
# Iteration 21: Remaining features: 127, Removed: prec_lag6h, RMSE: 0.3440, R²: 0.3482
# Iteration 22: Remaining features: 126, Removed: ts_0.3_gfXG_lag3h, RMSE: 0.3478, R²: 0.3320
# Iteration 23: Remaining features: 125, Removed: ts_0.3_gfXG_lag6h, RMSE: 0.3487, R²: 0.3307
# Iteration 24: Remaining features: 124, Removed: wfps_0.05_gfXG_lag9h, RMSE: 0.3481, R²: 0.3330
# Iteration 25: Remaining features: 123, Removed: prec_lag9h_roll3hsum, RMSE: 0.3480, R²: 0.3305
# Iteration 26: Remaining features: 122, Removed: ts_0.15_gfXG_diff6h, RMSE: 0.3508, R²: 0.3204
# Iteration 27: Remaining features: 121, Removed: prec_lag6h_roll6hsum, RMSE: 0.3481, R²: 0.3311
# Iteration 28: Remaining features: 120, Removed: wfps_0.15_gfXG_lag3h, RMSE: 0.3494, R²: 0.3276
# Iteration 29: Remaining features: 119, Removed: wfps_0.15_gfXG_lag9h, RMSE: 0.3485, R²: 0.3297
# Iteration 30: Remaining features: 118, Removed: ts_0.05_gfXG_roll9hmean, RMSE: 0.3498, R²: 0.3231
# Iteration 31: Remaining features: 117, Removed: wfps_0.15_gfXG_lag6h, RMSE: 0.3485, R²: 0.3266
# Iteration 32: Remaining features: 116, Removed: wfps_0.15_gfXG_lag3h_roll9hmean, RMSE: 0.3509, R²: 0.3197
# Iteration 33: Remaining features: 115, Removed: wfps_0.3_gfXG_lag3h, RMSE: 0.3493, R²: 0.3241
# Iteration 34: Remaining features: 114, Removed: GPP_U50_f_reddyproc_lag6h_roll3hsum, RMSE: 0.3525, R²: 0.3139
# Iteration 35: Remaining features: 113, Removed: wfps_0.15_gfXG_lag6h_roll3hmean, RMSE: 0.3508, R²: 0.3219
# Iteration 36: Remaining features: 112, Removed: ts_0.3_gfXG_lag9h, RMSE: 0.3518, R²: 0.3160
# Iteration 37: Remaining features: 111, Removed: wfps_0.15_gfXG_roll9hmean, RMSE: 0.3540, R²: 0.3068
# Iteration 38: Remaining features: 110, Removed: wfps_0.3_gfXG_lag6h, RMSE: 0.3523, R²: 0.3154
# Iteration 39: Remaining features: 109, Removed: wfps_0.3_gfXG_lag9h, RMSE: 0.3508, R²: 0.3211
# Iteration 40: Remaining features: 108, Removed: GPP_U50_f_reddyproc_lag3h_roll9hsum, RMSE: 0.3531, R²: 0.3128
# Iteration 41: Remaining features: 107, Removed: GPP_U50_f_reddyproc_lag6h_roll6hsum, RMSE: 0.3465, R²: 0.3373
# Iteration 42: Remaining features: 106, Removed: wfps_0.15_gfXG_lag9h_roll3hmean, RMSE: 0.3473, R²: 0.3332
# Iteration 43: Remaining features: 105, Removed: ts_0.05_gfXG_diff24h, RMSE: 0.3488, R²: 0.3293
# Iteration 44: Remaining features: 104, Removed: ts_0.15_gfXG_diff12h, RMSE: 0.3456, R²: 0.3407
# Iteration 45: Remaining features: 103, Removed: ts_0.15_gfXG_lag9h_roll3hmean, RMSE: 0.3483, R²: 0.3290
# Iteration 46: Remaining features: 102, Removed: wfps_0.05_gfXG_lag3h, RMSE: 0.3492, R²: 0.3269
# Iteration 47: Remaining features: 101, Removed: wfps_0.05_gfXG_lag6h, RMSE: 0.3484, R²: 0.3298
# Iteration 48: Remaining features: 100, Removed: prec_roll3hsum, RMSE: 0.3451, R²: 0.3417
# Iteration 49: Remaining features: 99, Removed: ts_0.05_gfXG_roll6hmean, RMSE: 0.3411, R²: 0.3600
# Iteration 50: Remaining features: 98, Removed: GPP_U50_f_reddyproc_roll3hsum, RMSE: 0.3481, R²: 0.3308
# Iteration 51: Remaining features: 97, Removed: ts_0.15_gfXG_roll9hmean, RMSE: 0.3501, R²: 0.3254
# Iteration 52: Remaining features: 96, Removed: GPP_U50_f_reddyproc_roll6hsum, RMSE: 0.3454, R²: 0.3421
# Iteration 53: Remaining features: 95, Removed: GPP_U50_f_reddyproc_roll9hsum, RMSE: 0.3435, R²: 0.3492
# Iteration 54: Remaining features: 94, Removed: prec_roll6hsum, RMSE: 0.3395, R²: 0.3682
# Iteration 55: Remaining features: 93, Removed: prec_roll9hsum, RMSE: 0.3416, R²: 0.3601
# Iteration 56: Remaining features: 92, Removed: ts_0.05_gfXG_roll3hmean, RMSE: 0.3396, R²: 0.3643
# Iteration 57: Remaining features: 91, Removed: ts_0.15_gfXG_roll3hmean, RMSE: 0.3422, R²: 0.3564
# Iteration 58: Remaining features: 90, Removed: ts_0.15_gfXG_roll6hmean, RMSE: 0.3403, R²: 0.3626
# Iteration 59: Remaining features: 89, Removed: ts_0.3_gfXG_roll3hmean, RMSE: 0.3455, R²: 0.3430
# Iteration 60: Remaining features: 88, Removed: ts_0.3_gfXG_roll6hmean, RMSE: 0.3437, R²: 0.3501
# Iteration 61: Remaining features: 87, Removed: ts_0.3_gfXG_roll9hmean, RMSE: 0.3463, R²: 0.3363
# Iteration 62: Remaining features: 86, Removed: GPP_U50_f_reddyproc_lag6h_roll9hsum, RMSE: 0.3468, R²: 0.3392
# Iteration 63: Remaining features: 85, Removed: GPP_U50_f_reddyproc_lag9h_roll6hsum, RMSE: 0.3433, R²: 0.3501
# Iteration 64: Remaining features: 84, Removed: wfps_0.3_gfXG_lag3h_roll9hmean, RMSE: 0.3482, R²: 0.3312
# Iteration 65: Remaining features: 83, Removed: GPP_U50_f_reddyproc_lag9h_roll3hsum, RMSE: 0.3470, R²: 0.3355
# Iteration 66: Remaining features: 82, Removed: wfps_0.05_gfXG_roll3hmean, RMSE: 0.3492, R²: 0.3277
# Iteration 67: Remaining features: 81, Removed: wfps_0.05_gfXG_roll6hmean, RMSE: 0.3457, R²: 0.3418
# Iteration 68: Remaining features: 80, Removed: wfps_0.15_gfXG_roll3hmean, RMSE: 0.3486, R²: 0.3292
# Iteration 69: Remaining features: 79, Removed: wfps_0.15_gfXG_lag3h_roll6hmean, RMSE: 0.3457, R²: 0.3421
# Iteration 70: Remaining features: 78, Removed: GPP_U50_f_reddyproc_lag9h_roll9hsum, RMSE: 0.3441, R²: 0.3470
# Iteration 71: Remaining features: 77, Removed: ts_0.05_gfXG_diff12h, RMSE: 0.3465, R²: 0.3375
# Iteration 72: Remaining features: 76, Removed: wfps_0.05_gfXG_roll9hmean, RMSE: 0.3411, R²: 0.3567
# Iteration 73: Remaining features: 75, Removed: wfps_0.15_gfXG_roll6hmean, RMSE: 0.3488, R²: 0.3232
# Iteration 74: Remaining features: 74, Removed: wfps_0.3_gfXG_roll3hmean, RMSE: 0.3486, R²: 0.3240
# Iteration 75: Remaining features: 73, Removed: wfps_0.3_gfXG_roll6hmean, RMSE: 0.3512, R²: 0.3148
# Iteration 76: Remaining features: 72, Removed: wfps_0.3_gfXG_roll9hmean, RMSE: 0.3462, R²: 0.3389
# Iteration 77: Remaining features: 71, Removed: prec_lag3h_roll3hsum, RMSE: 0.3476, R²: 0.3312
# Iteration 78: Remaining features: 70, Removed: prec_lag3h_roll6hsum, RMSE: 0.3492, R²: 0.3277
# Iteration 79: Remaining features: 69, Removed: prec_lag6h_roll3hsum, RMSE: 0.3483, R²: 0.3264
# Iteration 80: Remaining features: 68, Removed: GPP_U50_f_reddyproc_lag3h_roll6hsum, RMSE: 0.3444, R²: 0.3433
# Iteration 81: Remaining features: 67, Removed: prec_lag3h_roll9hsum, RMSE: 0.3491, R²: 0.3259
# Iteration 82: Remaining features: 66, Removed: ts_0.05_gfXG_lag6h_roll3hmean, RMSE: 0.3506, R²: 0.3151
# Iteration 83: Remaining features: 65, Removed: ts_0.05_gfXG_lag3h_roll3hmean, RMSE: 0.3455, R²: 0.3385
# Iteration 84: Remaining features: 64, Removed: ts_0.05_gfXG_lag3h_roll6hmean, RMSE: 0.3462, R²: 0.3351
# Iteration 85: Remaining features: 63, Removed: prec_lag6h_roll9hsum, RMSE: 0.3527, R²: 0.3106
# Iteration 86: Remaining features: 62, Removed: prec_lag9h_roll6hsum, RMSE: 0.3498, R²: 0.3201
# Iteration 87: Remaining features: 61, Removed: prec_lag9h_roll9hsum, RMSE: 0.3553, R²: 0.2946
# Iteration 88: Remaining features: 60, Removed: ts_0.05_gfXG_lag6h_roll6hmean, RMSE: 0.3498, R²: 0.3196
# Iteration 89: Remaining features: 59, Removed: ts_0.05_gfXG_lag6h_roll9hmean, RMSE: 0.3533, R²: 0.3073
# Iteration 90: Remaining features: 58, Removed: ts_0.3_gfXG_diff12h, RMSE: 0.3448, R²: 0.3417
# Iteration 91: Remaining features: 57, Removed: wfps_0.05_gfXG_lag6h_roll6hmean, RMSE: 0.3471, R²: 0.3314
# Iteration 92: Remaining features: 56, Removed: wfps_0.15_gfXG_diff6h, RMSE: 0.3459, R²: 0.3373
# Iteration 93: Remaining features: 55, Removed: GPP_U50_f_reddyproc_lag3h_roll3hsum, RMSE: 0.3480, R²: 0.3247
# Iteration 94: Remaining features: 54, Removed: ts_0.05_gfXG_lag9h_roll6hmean, RMSE: 0.3521, R²: 0.3126
# Iteration 95: Remaining features: 53, Removed: ts_0.15_gfXG_lag6h_roll3hmean, RMSE: 0.3540, R²: 0.3054
# Iteration 96: Remaining features: 52, Removed: wfps_0.15_gfXG_diff12h, RMSE: 0.3520, R²: 0.3147
# Iteration 97: Remaining features: 51, Removed: wfps_0.05_gfXG_lag3h_roll6hmean, RMSE: 0.3528, R²: 0.3080
# Iteration 98: Remaining features: 50, Removed: ts_0.15_gfXG_diff24h, RMSE: 0.3533, R²: 0.3064
# Iteration 99: Remaining features: 49, Removed: ts_0.3_gfXG_diff6h, RMSE: 0.3483, R²: 0.3294
# Iteration 100: Remaining features: 48, Removed: ts_0.15_gfXG_lag3h_roll3hmean, RMSE: 0.3500, R²: 0.3158
# Iteration 101: Remaining features: 47, Removed: ts_0.3_gfXG_lag6h_roll3hmean, RMSE: 0.3503, R²: 0.3195
# Iteration 102: Remaining features: 46, Removed: ts_0.15_gfXG_lag6h_roll6hmean, RMSE: 0.3483, R²: 0.3253
# Iteration 103: Remaining features: 45, Removed: wfps_0.3_gfXG_lag6h_roll3hmean, RMSE: 0.3545, R²: 0.3015
# Iteration 104: Remaining features: 44, Removed: ts_0.15_gfXG_lag3h_roll9hmean, RMSE: 0.3552, R²: 0.2990
# Iteration 105: Remaining features: 43, Removed: wfps_0.3_gfXG_diff24h, RMSE: 0.3527, R²: 0.3103
# Iteration 106: Remaining features: 42, Removed: wfps_0.15_gfXG_lag6h_roll6hmean, RMSE: 0.3548, R²: 0.3029
# Iteration 107: Remaining features: 41, Removed: ts_0.3_gfXG_lag3h_roll6hmean, RMSE: 0.3496, R²: 0.3251
# Iteration 108: Remaining features: 40, Removed: wfps_0.05_gfXG_diff12h, RMSE: 0.3505, R²: 0.3180
# Iteration 109: Remaining features: 39, Removed: wfps_0.15_gfXG_lag9h_roll6hmean, RMSE: 0.3502, R²: 0.3228
# Iteration 110: Remaining features: 38, Removed: wfps_0.3_gfXG_diff6h, RMSE: 0.3505, R²: 0.3181
# Iteration 111: Remaining features: 37, Removed: wfps_0.3_gfXG_diff12h, RMSE: 0.3506, R²: 0.3187
# Iteration 112: Remaining features: 36, Removed: wfps_0.15_gfXG_lag3h_roll3hmean, RMSE: 0.3501, R²: 0.3236
# Iteration 113: Remaining features: 35, Removed: wfps_0.3_gfXG_lag3h_roll3hmean, RMSE: 0.3479, R²: 0.3343
# Iteration 114: Remaining features: 34, Removed: wfps_0.05_gfXG_lag3h_roll9hmean, RMSE: 0.3471, R²: 0.3330
# Iteration 115: Remaining features: 33, Removed: wfps_0.3_gfXG_lag6h_roll6hmean, RMSE: 0.3485, R²: 0.3289
# Iteration 116: Remaining features: 32, Removed: wfps_0.15_gfXG_lag6h_roll9hmean, RMSE: 0.3487, R²: 0.3279
# Iteration 117: Remaining features: 31, Removed: wfps_0.3_gfXG_lag9h_roll6hmean, RMSE: 0.3471, R²: 0.3334
# Iteration 118: Remaining features: 30, Removed: wfps_0.3_gfXG_lag6h_roll9hmean, RMSE: 0.3471, R²: 0.3372
# Iteration 119: Remaining features: 29, Removed: wfps_0.05_gfXG_diff6h, RMSE: 0.3496, R²: 0.3234
# Iteration 120: Remaining features: 28, Removed: wfps_0.3_gfXG_lag9h_roll3hmean, RMSE: 0.3538, R²: 0.3075
# Iteration 121: Remaining features: 27, Removed: ts_0.05_gfXG_lag9h_roll9hmean, RMSE: 0.3531, R²: 0.3092
# Iteration 122: Remaining features: 26, Removed: ts_0.15_gfXG_lag3h_roll6hmean, RMSE: 0.3603, R²: 0.2800
# Iteration 123: Remaining features: 25, Removed: ts_0.15_gfXG_lag6h_roll9hmean, RMSE: 0.3547, R²: 0.3018
# Iteration 124: Remaining features: 24, Removed: ts_0.15_gfXG_lag9h_roll6hmean, RMSE: 0.3611, R²: 0.2757
# Iteration 125: Remaining features: 23, Removed: ts_0.15_gfXG_lag9h_roll9hmean, RMSE: 0.3591, R²: 0.2890
# Iteration 126: Remaining features: 22, Removed: wfps_0.05_gfXG_lag6h_roll9hmean, RMSE: 0.3610, R²: 0.2722
# Iteration 127: Remaining features: 21, Removed: ts_0.3_gfXG_lag3h_roll3hmean, RMSE: 0.3558, R²: 0.2953
# Iteration 128: Remaining features: 20, Removed: ts_0.3_gfXG_lag3h_roll9hmean, RMSE: 0.3541, R²: 0.3037
# Iteration 129: Remaining features: 19, Removed: wfps_0.15_gfXG_lag9h_roll9hmean, RMSE: 0.3584, R²: 0.2855
# Iteration 130: Remaining features: 18, Removed: wfps_0.05_gfXG_diff24h, RMSE: 0.3619, R²: 0.2679
# Iteration 131: Remaining features: 17, Removed: wfps_0.3_gfXG_lag3h_roll6hmean, RMSE: 0.3606, R²: 0.2779
# Iteration 132: Remaining features: 16, Removed: wfps_0.05_gfXG_lag9h_roll3hmean, RMSE: 0.3620, R²: 0.2695
# Iteration 133: Remaining features: 15, Removed: ts_0.3_gfXG_lag6h_roll6hmean, RMSE: 0.3630, R²: 0.2662
# Iteration 134: Remaining features: 14, Removed: wfps_0.15_gfXG_diff24h, RMSE: 0.3567, R²: 0.2945
# Iteration 135: Remaining features: 13, Removed: GPP_U50_f_reddyproc, RMSE: 0.3509, R²: 0.3194
# Iteration 136: Remaining features: 12, Removed: wfps_0.05_gfXG_lag9h_roll6hmean, RMSE: 0.3534, R²: 0.3131
# Iteration 137: Remaining features: 11, Removed: ts_0.3_gfXG_lag6h_roll9hmean, RMSE: 0.3552, R²: 0.3028
# Iteration 138: Remaining features: 10, Removed: ts_0.3_gfXG_lag9h_roll3hmean, RMSE: 0.3592, R²: 0.2872
# Iteration 139: Remaining features: 9, Removed: wfps_0.05_gfXG_lag3h_roll3hmean, RMSE: 0.3587, R²: 0.2872
# Iteration 140: Remaining features: 8, Removed: wfps_0.05_gfXG_lag9h_roll9hmean, RMSE: 0.3593, R²: 0.2776
# Iteration 141: Remaining features: 7, Removed: wfps_0.05_gfXG_lag6h_roll3hmean, RMSE: 0.3597, R²: 0.2790
# Iteration 142: Remaining features: 6, Removed: ts_0.3_gfXG_diff24h, RMSE: 0.3653, R²: 0.2592
# Iteration 143: Remaining features: 5, Removed: ts_0.3_gfXG_lag9h_roll6hmean, RMSE: 0.3564, R²: 0.2953
# Iteration 144: Remaining features: 4, Removed: wfps_0.3_gfXG_lag9h_roll9hmean, RMSE: 0.3640, R²: 0.2601
# Iteration 145: Remaining features: 3, Removed: ts_0.05_gfXG_diff6h, RMSE: 0.3755, R²: 0.2189
# Iteration 146: Remaining features: 2, Removed: ts_0.3_gfXG_lag9h_roll9hmean, RMSE: 0.3877, R²: 0.1611
# Iteration 147: Remaining features: 1, Removed: n_decay_timed, RMSE: 0.4073, R²: 0.0745
# Best feature set found at iteration 135:
# Selected Features: ['GPP_U50_f_reddyproc', 'n_decay_timed', 'timesince_fert', 'ts_0.3_gfXG_lag6h_roll9hmean', 'ts_0.3_gfXG_lag9h_roll3hmean', 'ts_0.3_gfXG_lag9h_roll6hmean', 'ts_0.3_gfXG_lag9h_roll9hmean', 'wfps_0.05_gfXG_lag3h_roll3hmean', 'wfps_0.05_gfXG_lag6h_roll3hmean', 'wfps_0.05_gfXG_lag9h_roll6hmean', 'wfps_0.05_gfXG_lag9h_roll9hmean', 'wfps_0.3_gfXG_lag9h_roll9hmean', 'ts_0.05_gfXG_diff6h', 'ts_0.3_gfXG_diff24h']
# Performance - RMSE: 0.3509, R²: 0.3194

# %% [markdown]
# # EXPORT

# %%
filename = 'best_features_' + TARGET_FLUX + '_' + MODEL_TYPE + '.txt'
with open(filename, 'w') as f:
    for item in selected_features:
        f.write(f"{item}\n")

filename = 'ranked_features_' + TARGET_FLUX + '_' + MODEL_TYPE + '.txt'
with open(filename, 'w') as f:
    for item in ranked_features:
        f.write(f"{item}\n")

# %% [markdown]
# # **End of notebook**

# %%
dt_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Finished {dt_string}")
# Out:
# Finished 2025-09-18 20:00:24
